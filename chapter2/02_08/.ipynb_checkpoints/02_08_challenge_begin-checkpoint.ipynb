# %% [markdown]
# ### Python module/package imports for this chapter

# %%
import math, json, collections, itertools

# %%
import numpy as np
import matplotlib.pyplot as pp
# %matplotlib inline

# %%
from mpl_toolkits.basemap import Basemap
import geopy

# %% [markdown]
# ### Code and data needed from previous videos

# %%
medal = collections.namedtuple('medal',['year','athlete','team','event'])
medals = [medal(*line.strip().split('\t')) for line in open('goldmedals.txt','r')]

# %% [markdown]
# ## Challenge solution
#
# #### Top 5 athletes with the most gold medals
# Correct

# %%
counter = collections.Counter(medal.athlete for medal in medals)

# %%
counter.most_common(5)
# Out:
# [('Paavo Nurmi', 9),
#  ('Carl Lewis', 9),
#  ('Usain Bolt', 9),
#  ('Ray Ewry', 8),
#  ('Allyson Felix', 6)]

# %% [markdown]
# #### Top 5 athletes who won gold medals in the largest variety of events
# Incorrect (check at the end for solution)

# %%
events = {medal.event for medal in medals}

# %%
events
# Out:
# {'10000m men',
#  '10000m walk men',
#  '10000m walk women',
#  '10000m women',
#  '100m',
#  '100m hurdles',
#  '100m hurdles women',
#  '100m men',
#  '100m women',
#  '10miles walk (16093m)',
#  '10miles walk (16093m) men',
#  '10miles walk (16093m) women',
#  '110m hurdles',
#  '110m hurdles men',
#  '1500m',
#  '1500m men',
#  '1500m women',
#  '200m',
#  '200m hurdles men',
#  '200m men',
#  '200m women',
#  '20km race walk women',
#  '20km walk',
#  '20km walk men',
#  '20km walk women',
#  '3000m steeplechase',
#  '3000m steeplechase men',
#  '3000m steeplechase women',
#  '3000m team men',
#  '3000m walk men',
#  '3000m women',
#  '3200m steeplechase men',
#  '3500m walk men',
#  '3miles team (4828m) men',
#  '4000m steeplechase men',
#  '400m',
#  '400m hurdles',
#  '400m hurdles men',
#  '400m hurdles women',
#  '400m men',
#  '400m women',
#  '4miles team men',
#  '4x100m relay',
#  '4x100m relay men',
#  '4x100m relay women',
#  '4x400m relay',
#  '4x400m relay men',
#  '4x400m relay women',
#  '5 miles (8047m) men',
#  '5000m men',
#  '5000m team',
#  '5000m team men',
#  '5000m team women',
#  '5000m women',
#  '50km walk',
#  '50km walk men',
#  '56lb weight throw (25.4kg) men',
#  '60m men',
#  '800m',
#  '800m men',
#  '800m women',
#  '80m hurdles women',
#  'cross country individual men',
#  'cross country team men',
#  'decathlon',
#  'decathlon men',
#  'discus throw',
#  'discus throw ancient style men',
#  'discus throw men',
#  'discus throw women',
#  'discus throw, both hands men',
#  'hammer throw',
#  'hammer throw men',
#  'hammer throw women',
#  'heptathlon',
#  'heptathlon women',
#  'high jump',
#  'high jump men',
#  'high jump women',
#  'high jump, standing men',
#  'javelin throw',
#  'javelin throw freestyle men',
#  'javelin throw men',
#  'javelin throw women',
#  'javelin throw, both hands men',
#  'long jump',
#  'long jump men',
#  'long jump women',
#  'long jump, standing men',
#  'marathon',
#  'marathon men',
#  'marathon women',
#  'pentathlon men',
#  'pentathlon women',
#  'pole vault',
#  'pole vault men',
#  'pole vault women',
#  'shot put',
#  'shot put men',
#  'shot put women',
#  'shot put, both hands men',
#  'triathlon (long jump / shot put / 100 yards)',
#  'triathlon (long jump / shot put / 100 yards) men',
#  'triathlon (long jump / shot put / 100 yards) women',
#  'triple jump',
#  'triple jump men',
#  'triple jump women',
#  'triple jump, standing men'}

# %%
athlete_and_event = collections.namedtuple('athlete_and_event', ['athlete', 'event'])

# %%
athletes_and_events = {athlete_and_event(medal.athlete, medal.event) for medal in medals}

# %%
athletes_and_events
# Out:
# {athlete_and_event(athlete='Sherone Simpson', event='4x100m relay women'),
#  athlete_and_event(athlete='Derrick Brew', event='4x400m relay men'),
#  athlete_and_event(athlete='Reginald Walker', event='100m men'),
#  athlete_and_event(athlete='Arnold Jackson', event='1500m men'),
#  athlete_and_event(athlete='Fanny Blankers-Koen', event='100m women'),
#  athlete_and_event(athlete='Walter Francis Davis', event='high jump men'),
#  athlete_and_event(athlete='James Ray Hines', event='100m men'),
#  athlete_and_event(athlete='Juha Tiainen', event='hammer throw men'),
#  athlete_and_event(athlete='Henry Argue Russell', event='4x100m relay men'),
#  athlete_and_event(athlete='Foy Draper', event='4x100m relay men'),
#  athlete_and_event(athlete='Helen Herring Stephens', event='100m women'),
#  athlete_and_event(athlete='Tell Schirnding Berna', event='3000m team men'),
#  athlete_and_event(athlete='Howard Valentine', event='4miles team men'),
#  athlete_and_event(athlete='Karin Richert-Balzer', event='80m hurdles women'),
#  athlete_and_event(athlete='Mizuki Noguchi', event='marathon women'),
#  athlete_and_event(athlete='Mathilde (Tilly) Fleischer', event='javelin throw women'),
#  athlete_and_event(athlete='Yanina Karolchik', event='shot put women'),
#  athlete_and_event(athlete='Jearl Miles', event='4x400m relay women'),
#  athlete_and_event(athlete='Betty Cuthbert', event='4x100m relay women'),
#  athlete_and_event(athlete='Ramon Miller', event='4x400m relay men'),
#  athlete_and_event(athlete='Marjorie Jackson', event='100m women'),
#  athlete_and_event(athlete='William Henry Nieder', event='shot put men'),
#  athlete_and_event(athlete='Carlette D. Guidry-White', event='4x100m relay women'),
#  athlete_and_event(athlete='Romy Müller', event='4x100m relay women'),
#  athlete_and_event(athlete='Thomas C. Smith', event='200m men'),
#  athlete_and_event(athlete='Elena Lashmanova', event='20km walk women'),
#  athlete_and_event(athlete='Ville Ritola', event='5000m men'),
#  athlete_and_event(athlete='Kevin Bernard Robinzine', event='4x400m relay men'),
#  athlete_and_event(athlete='Ralph Metcalfe', event='4x100m relay men'),
#  athlete_and_event(athlete='Annette Joan Rogers', event='4x100m relay women'),
#  athlete_and_event(athlete='Otis Crandall Davis', event='400m men'),
#  athlete_and_event(athlete='Warren (Rex) Jay Cawley', event='400m hurdles men'),
#  athlete_and_event(athlete='Monika Zehrt', event='4x400m relay women'),
#  athlete_and_event(athlete='Ria G. Stalman', event='discus throw women'),
#  athlete_and_event(athlete='Wladyslaw Komar', event='shot put men'),
#  athlete_and_event(athlete='Ulf Timmermann', event='shot put men'),
#  athlete_and_event(athlete='Thomas Munkelt', event='110m hurdles men'),
#  athlete_and_event(athlete='Miruts Yifter', event='5000m men'),
#  athlete_and_event(athlete='Robert Korzeniowski', event='50km walk men'),
#  athlete_and_event(athlete='David Henry Jacobs', event='4x100m relay men'),
#  athlete_and_event(athlete='Melaine Walker', event='400m hurdles women'),
#  athlete_and_event(athlete='Marjorie Jackson', event='200m women'),
#  athlete_and_event(athlete='Tim Montgomery', event='4x100m relay men'),
#  athlete_and_event(athlete='Ray Ewry', event='long jump, standing men'),
#  athlete_and_event(athlete='Charles Bennett', event='1500m men'),
#  athlete_and_event(athlete='Archie Hahn', event='60m men'),
#  athlete_and_event(athlete='James Lightbody', event='1500m men'),
#  athlete_and_event(athlete='John Ngugi', event='5000m men'),
#  athlete_and_event(athlete='Yelena Rouzina', event='4x400m relay women'),
#  athlete_and_event(athlete='Ville Ritola', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Daniel Plaza montero', event='20km walk men'),
#  athlete_and_event(athlete='Renaud Lavillenie', event='pole vault men'),
#  athlete_and_event(athlete='Usain Bolt', event='100m'),
#  athlete_and_event(athlete='Phyllis Francis', event='4x400m relay'),
#  athlete_and_event(athlete='Alvin Kraenzlein', event='long jump men'),
#  athlete_and_event(athlete='Aksana Miankova', event='hammer throw women'),
#  athlete_and_event(athlete='Valerie Adams', event='shot put women'),
#  athlete_and_event(athlete='Harrison Dillard', event='110m hurdles men'),
#  athlete_and_event(athlete='Frederick Morgan Hansen', event='pole vault men'),
#  athlete_and_event(athlete='Jonathan David Edwards', event='triple jump men'),
#  athlete_and_event(athlete='Vladimir Kiselev', event='shot put men'),
#  athlete_and_event(athlete='Kyle Clemons', event='4x400m relay'),
#  athlete_and_event(athlete='Arthur James Robertson', event='3miles team (4828m) men'),
#  athlete_and_event(athlete='Michael Marsh', event='200m men'),
#  athlete_and_event(athlete='Gerd Wessig', event='high jump men'),
#  athlete_and_event(athlete='Jeff Henderson', event='long jump'),
#  athlete_and_event(athlete='Faith Chepngetich Kipyegon', event='1500m'),
#  athlete_and_event(athlete='Maricica Puica', event='3000m women'),
#  athlete_and_event(athlete='William Samuel Steele', event='long jump men'),
#  athlete_and_event(athlete='Martin Emmett Toppino', event='4x100m relay men'),
#  athlete_and_event(athlete='Vasili Rudenkov', event='hammer throw men'),
#  athlete_and_event(athlete='Ghada Shouaa', event='heptathlon women'),
#  athlete_and_event(athlete='Heli Orvokki Rantanen', event='javelin throw women'),
#  athlete_and_event(athlete='Jean Galfione', event='pole vault men'),
#  athlete_and_event(athlete='Nesta Carter', event='4x100m relay men'),
#  athlete_and_event(athlete='Hicham El guerrouj', event='5000m men'),
#  athlete_and_event(athlete='Lashawn Merritt', event='4x400m relay'),
#  athlete_and_event(athlete='Roger Kingdom', event='110m hurdles men'),
#  athlete_and_event(athlete='Deon Marie Hemmings', event='400m hurdles women'),
#  athlete_and_event(athlete='Lauryn Williams', event='4x100m relay women'),
#  athlete_and_event(athlete='Amos Kipwabok Biwott', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Lee Edward Evans', event='4x400m relay men'),
#  athlete_and_event(athlete='Eric Henry Liddell', event='400m men'),
#  athlete_and_event(athlete='Fanny Rosenfeld', event='4x100m relay women'),
#  athlete_and_event(athlete='Micheline Ostermeyer', event='shot put women'),
#  athlete_and_event(athlete='Jenna Prandini', event='4x100m relay'),
#  athlete_and_event(athlete='Ellen Stropahl-Streidt', event='4x400m relay women'),
#  athlete_and_event(athlete='Arne Ahman', event='triple jump men'),
#  athlete_and_event(athlete='Yohan Blake', event='4x100m relay men'),
#  athlete_and_event(athlete='Sally Pearson', event='100m hurdles women'),
#  athlete_and_event(athlete='Christoph Höhne', event='50km walk men'),
#  athlete_and_event(athlete='James Edwin Meredith', event='800m men'),
#  athlete_and_event(athlete='Dagmar Käsling', event='4x400m relay women'),
#  athlete_and_event(athlete='Ellery Clark', event='high jump men'),
#  athlete_and_event(athlete='Jeneba Tarmoh', event='4x100m relay women'),
#  athlete_and_event(athlete='Frej Liewendhal', event='3000m team men'),
#  athlete_and_event(athlete='Earle Elmer Meadows', event='pole vault men'),
#  athlete_and_event(athlete='Henry Eriksson', event='1500m men'),
#  athlete_and_event(athlete='Beverly Mcdonald', event='4x100m relay women'),
#  athlete_and_event(athlete='David Curtis Munson', event='4miles team men'),
#  athlete_and_event(athlete='Gaston Etienne Reiff', event='5000m men'),
#  athlete_and_event(athlete='Paavo Nurmi', event='cross country individual men'),
#  athlete_and_event(athlete='Chandra Danette Cheeseborough', event='4x400m relay women'),
#  athlete_and_event(athlete='Shirley Strickland-De La Hunty', event='80m hurdles women'),
#  athlete_and_event(athlete='Michael Johnson', event='400m men'),
#  athlete_and_event(athlete='Iolanda Balas', event='high jump women'),
#  athlete_and_event(athlete='Wyomia Tyus', event='4x100m relay women'),
#  athlete_and_event(athlete='David Neville', event='4x400m relay men'),
#  athlete_and_event(athlete='Francoise Mbango etone', event='triple jump women'),
#  athlete_and_event(athlete='Roy Braxton Cochran', event='4x400m relay men'),
#  athlete_and_event(athlete='Sergei Litvinov', event='hammer throw men'),
#  athlete_and_event(athlete='Ludmila Engquist', event='100m hurdles women'),
#  athlete_and_event(athlete='Wyndham Halswelle', event='400m men'),
#  athlete_and_event(athlete='Maicel Malone', event='4x400m relay women'),
#  athlete_and_event(athlete='Micheline Ostermeyer', event='discus throw women'),
#  athlete_and_event(athlete='Jackie Joyner-Kersee', event='long jump women'),
#  athlete_and_event(athlete='Vincent George Rhoden', event='4x400m relay men'),
#  athlete_and_event(athlete='Charles Paddock', event='4x100m relay men'),
#  athlete_and_event(athlete='Paul Ereng', event='800m men'),
#  athlete_and_event(athlete='Evelyn Furtsch', event='4x100m relay women'),
#  athlete_and_event(athlete='Giuseppe Dordoni', event='50km walk men'),
#  athlete_and_event(athlete='Chuhei Nambu', event='triple jump men'),
#  athlete_and_event(athlete='Horace III Ashenfelter', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Thomas William Courtney', event='800m men'),
#  athlete_and_event(athlete='Yuri Sedykh', event='hammer throw men'),
#  athlete_and_event(athlete='Sanya Richards-Ross', event='400m women'),
#  athlete_and_event(athlete='Chryste Gaines', event='4x100m relay women'),
#  athlete_and_event(athlete='Benita Fitzgerald-Brown', event='100m hurdles women'),
#  athlete_and_event(athlete='Halina Herrmann-Gorecka-Richter', event='4x100m relay women'),
#  athlete_and_event(athlete='Frank Charles Shorter', event='marathon men'),
#  athlete_and_event(athlete='Paula Ivan', event='1500m women'),
#  athlete_and_event(athlete='Daniel Everett', event='4x400m relay men'),
#  athlete_and_event(athlete='Charles Dvorak', event='pole vault men'),
#  athlete_and_event(athlete='Hans Woellke', event='shot put men'),
#  athlete_and_event(athlete='Natalya Sadova', event='discus throw women'),
#  athlete_and_event(athlete='Faina Melnik', event='discus throw women'),
#  athlete_and_event(athlete='George Goulding', event='10000m walk men'),
#  athlete_and_event(athlete='Tatiana Kazankina', event='1500m women'),
#  athlete_and_event(athlete='Percy Hodge', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Viktor Markin', event='400m men'),
#  athlete_and_event(athlete='Robert Joseph Morrow', event='200m men'),
#  athlete_and_event(athlete='Herbert Elliott', event='1500m men'),
#  athlete_and_event(athlete='Arsi Harju', event='shot put men'),
#  athlete_and_event(athlete='Valerie Vili', event='shot put women'),
#  athlete_and_event(athlete='Lawrence J. Black', event='4x100m relay men'),
#  athlete_and_event(athlete='William Bruce Jenner', event='decathlon men'),
#  athlete_and_event(athlete='Bruny Surin', event='4x100m relay men'),
#  athlete_and_event(athlete='David James Wottle', event='800m men'),
#  athlete_and_event(athlete='Patrick Mcdonald', event='56lb weight throw (25.4kg) men'),
#  athlete_and_event(athlete='Anthuan Maybank', event='4x400m relay men'),
#  athlete_and_event(athlete='Doina Besliu-Melinte', event='800m women'),
#  athlete_and_event(athlete='Douglas Gordon Lowe', event='800m men'),
#  athlete_and_event(athlete='Michel Theato', event='marathon men'),
#  athlete_and_event(athlete='Robert Harting', event='discus throw men'),
#  athlete_and_event(athlete='Ding Chen', event='20km walk men'),
#  athlete_and_event(athlete='Leo Joseph Sexton', event='shot put men'),
#  athlete_and_event(athlete='Randel Luvelle Williams', event='long jump men'),
#  athlete_and_event(athlete='Myrtle Alice Cook', event='4x100m relay women'),
#  athlete_and_event(athlete='Harri Edvin Larva', event='1500m men'),
#  athlete_and_event(athlete='Evgeniya Polyakova', event='4x100m relay women'),
#  athlete_and_event(athlete='Eliud Kipchoge', event='marathon'),
#  athlete_and_event(athlete='Heikki Liimatainen', event='cross country team men'),
#  athlete_and_event(athlete='Omar Mcleod', event='110m hurdles'),
#  athlete_and_event(athlete='Francena McCorory', event='4x400m relay women'),
#  athlete_and_event(athlete='Spyridon Louis', event='marathon men'),
#  athlete_and_event(athlete='LaShawn Merritt', event='400m men'),
#  athlete_and_event(athlete='Carl Lewis', event='100m men'),
#  athlete_and_event(athlete='Moulay Brahim Boutayeb', event='10000m men'),
#  athlete_and_event(athlete="Victor Henry Augustus D'arcy", event='4x100m relay men'),
#  athlete_and_event(athlete='Allen Johnson', event='110m hurdles men'),
#  athlete_and_event(athlete='Walter B. John Tewksbury', event='400m hurdles men'),
#  athlete_and_event(athlete='John Eke', event='cross country team men'),
#  athlete_and_event(athlete='Christina Brehmer-Lathan', event='4x400m relay women'),
#  athlete_and_event(athlete='John Joseph Hayes', event='marathon men'),
#  athlete_and_event(athlete='William Stephenson', event='4x400m relay men'),
#  athlete_and_event(athlete='Nawal El moutawakel', event='400m hurdles women'),
#  athlete_and_event(athlete='Inessa Kravets', event='triple jump women'),
#  athlete_and_event(athlete='John Mikaelsson', event='10000m walk men'),
#  athlete_and_event(athlete='Petra Felke-Meier', event='javelin throw women'),
#  athlete_and_event(athlete='Harriett Claiborne Bland', event='4x100m relay women'),
#  athlete_and_event(athlete='Mark Mckoy', event='110m hurdles men'),
#  athlete_and_event(athlete='Donald George Bragg', event='pole vault men'),
#  athlete_and_event(athlete='Joanna Hayes', event='100m hurdles women'),
#  athlete_and_event(athlete='Malcolm Maurice Wilkins', event='discus throw men'),
#  athlete_and_event(athlete='Robert Joseph Morrow', event='100m men'),
#  athlete_and_event(athlete='Remigius Valiulis', event='4x400m relay men'),
#  athlete_and_event(athlete='Viktor Tsybulenko', event='javelin throw men'),
#  athlete_and_event(athlete='Alex Schwazer', event='50km walk men'),
#  athlete_and_event(athlete='Allyson Felix', event='4x100m relay women'),
#  athlete_and_event(athlete='Jackson Scholz', event='4x100m relay men'),
#  athlete_and_event(athlete='Yordanka Donkova', event='100m hurdles women'),
#  athlete_and_event(athlete='Wilma Rudolph', event='100m women'),
#  athlete_and_event(athlete='Harold Abrahams', event='100m men'),
#  athlete_and_event(athlete='Mildred Didrikson', event='javelin throw women'),
#  athlete_and_event(athlete='Carlos Lopes', event='marathon men'),
#  athlete_and_event(athlete='Thomas Burke', event='100m men'),
#  athlete_and_event(athlete='Glyniss Leanne Nunn-Saunders-Cearns', event='heptathlon women'),
#  athlete_and_event(athlete='Annegret Richter-Irrgang', event='4x100m relay women'),
#  athlete_and_event(athlete='Angela Voigt', event='long jump women'),
#  athlete_and_event(athlete='Maritza Marten', event='discus throw women'),
#  athlete_and_event(athlete='Paavo Ilmari Yrjölä', event='decathlon men'),
#  athlete_and_event(athlete='Imre Nemeth', event='hammer throw men'),
#  athlete_and_event(athlete='Gerda Johanna Marie Van der kade-Koudijs', event='4x100m relay women'),
#  athlete_and_event(athlete='Jason Gardener', event='4x100m relay men'),
#  athlete_and_event(athlete='Astrid Kumbernuss', event='shot put women'),
#  athlete_and_event(athlete='Andre Lamar Phillips', event='400m hurdles men'),
#  athlete_and_event(athlete='Alice Marie Coachman', event='high jump women'),
#  athlete_and_event(athlete='Leroy Burrell', event='4x100m relay men'),
#  athlete_and_event(athlete='Steve Lewis', event='400m men'),
#  athlete_and_event(athlete='Fanny Blankers-Koen', event='4x100m relay women'),
#  athlete_and_event(athlete='Tatyana Samolenko-Dorovskikh', event='3000m women'),
#  athlete_and_event(athlete='Evelyn Ashford', event='4x100m relay women'),
#  athlete_and_event(athlete='Kennedy Kane Mcarthur', event='marathon men'),
#  athlete_and_event(athlete='Maurice Greene', event='4x100m relay men'),
#  athlete_and_event(athlete='Vera Komisova', event='100m hurdles women'),
#  athlete_and_event(athlete='Christian Taylor', event='triple jump'),
#  athlete_and_event(athlete='Hannes Kolehmainen', event='5000m men'),
#  athlete_and_event(athlete='Alain Mimoun', event='marathon men'),
#  athlete_and_event(athlete='David Lekuta Rudisha', event='800m men'),
#  athlete_and_event(athlete='Nancy jebet Langat', event='1500m women'),
#  athlete_and_event(athlete='William Coales', event='3miles team (4828m) men'),
#  athlete_and_event(athlete='Millon Wolde', event='5000m men'),
#  athlete_and_event(athlete='Sevatheda Fynes', event='4x100m relay women'),
#  athlete_and_event(athlete='Raymond James Barbuti', event='4x400m relay men'),
#  athlete_and_event(athlete='Archibald Franklin Williams', event='400m men'),
#  athlete_and_event(athlete='Fanny Blankers-Koen', event='200m women'),
#  athlete_and_event(athlete='Malvin Groston Whitfield', event='4x400m relay men'),
#  athlete_and_event(athlete='Jesse Owens', event='200m men'),
#  athlete_and_event(athlete='Rita Kühne', event='4x400m relay women'),
#  athlete_and_event(athlete='Andreas Thorkildsen', event='javelin throw men'),
#  athlete_and_event(athlete='Vincent Edward Matthews', event='4x400m relay men'),
#  athlete_and_event(athlete='Henry Maitland Mackintosh', event='4x100m relay men'),
#  athlete_and_event(athlete='Lasse Viren', event='5000m men'),
#  athlete_and_event(athlete='Kitei Son', event='marathon men'),
#  athlete_and_event(athlete='Tatyana Lebedeva', event='long jump women'),
#  athlete_and_event(athlete='Yuriy Bilonog', event='shot put men'),
#  athlete_and_event(athlete='Natalya Lisovskaya', event='shot put women'),
#  athlete_and_event(athlete='William Patrick Jr. O', event='shot put men'),
#  athlete_and_event(athlete='Thiago Braz Da Silva', event='pole vault'),
#  athlete_and_event(athlete='Darold Williamson', event='4x400m relay men'),
#  athlete_and_event(athlete='Asafa Powell', event='4x100m relay men'),
#  athlete_and_event(athlete='Taylor Ellis-Watson', event='4x400m relay'),
#  athlete_and_event(athlete='Maurizio Damilano', event='20km walk men'),
#  athlete_and_event(athlete='Nafissatou Thiam', event='heptathlon'),
#  athlete_and_event(athlete='Ariana Washington', event='4x100m relay'),
#  athlete_and_event(athlete='Joseph Nathaniel Jr. Deloach', event='200m men'),
#  athlete_and_event(athlete='Earl Thomson', event='110m hurdles men'),
#  athlete_and_event(athlete='Athanasia Tsoumeleka', event='20km race walk women'),
#  athlete_and_event(athlete='Viktor Bryzgin', event='4x100m relay men'),
#  athlete_and_event(athlete='Darren Campbell', event='4x100m relay men'),
#  athlete_and_event(athlete='Jeremy Wariner', event='400m men'),
#  athlete_and_event(athlete='Godfrey Lionel Rampling', event='4x400m relay men'),
#  athlete_and_event(athlete='Allan Wells', event='100m men'),
#  athlete_and_event(athlete='Leslie Laing', event='4x400m relay men'),
#  athlete_and_event(athlete='Paraskevi Voula Patoulidou', event='100m hurdles women'),
#  athlete_and_event(athlete='John Youie Woodruff', event='800m men'),
#  athlete_and_event(athlete='Lioudmila Djigalova', event='4x400m relay women'),
#  athlete_and_event(athlete='Stefka Kostadinova', event='high jump women'),
#  athlete_and_event(athlete='Hector Monroe Dyer', event='4x100m relay men'),
#  athlete_and_event(athlete='Forrest Grady Towns', event='110m hurdles men'),
#  athlete_and_event(athlete='Ingrid Becker-Mickler', event='pentathlon women'),
#  athlete_and_event(athlete='Adolfo Consolini', event='discus throw men'),
#  athlete_and_event(athlete='Armas Rudolf Taipale', event='discus throw, both hands men'),
#  athlete_and_event(athlete='Vincent George Rhoden', event='400m men'),
#  athlete_and_event(athlete='Armin Hary', event='100m men'),
#  athlete_and_event(athlete='Irena Szewinska', event='200m women'),
#  athlete_and_event(athlete='Jim Thorpe', event='pentathlon men'),
#  athlete_and_event(athlete='Ferdinand Reinhardt Bie', event='pentathlon men'),
#  athlete_and_event(athlete='Michael Denny Larrabee', event='400m men'),
#  athlete_and_event(athlete='Tatiana Kazankina', event='800m women'),
#  athlete_and_event(athlete='Gwen Torrence', event='4x100m relay women'),
#  athlete_and_event(athlete='Toivo Aarne Loukola', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Olga Bryzgina', event='4x400m relay women'),
#  athlete_and_event(athlete='David George Burghley', event='400m hurdles men'),
#  athlete_and_event(athlete='Michael Denny Larrabee', event='4x400m relay men'),
#  athlete_and_event(athlete='Sergey Kliugin', event='high jump men'),
#  athlete_and_event(athlete='George Lawrence James', event='4x400m relay men'),
#  athlete_and_event(athlete='George Edward Larner', event='10miles walk (16093m) men'),
#  athlete_and_event(athlete='Gaston Roelants', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Tapio Korjus', event='javelin throw men'),
#  athlete_and_event(athlete='Arman Hall', event='4x400m relay'),
#  athlete_and_event(athlete='Michael Johnson', event='4x400m relay men'),
#  athlete_and_event(athlete='Willie Davenport', event='110m hurdles men'),
#  athlete_and_event(athlete='Christian Olsson', event='triple jump men'),
#  athlete_and_event(athlete='Keshia Baker', event='4x400m relay women'),
#  athlete_and_event(athlete='Robert Hayes', event='100m men'),
#  athlete_and_event(athlete='Andrey Perlov', event='50km walk men'),
#  athlete_and_event(athlete='Paavo Nurmi', event='10000m men'),
#  athlete_and_event(athlete='Martin Lauer', event='4x100m relay men'),
#  athlete_and_event(athlete='Eero Reino Lehtonen', event='pentathlon men'),
#  athlete_and_event(athlete='Ludvik Danek', event='discus throw men'),
#  athlete_and_event(athlete='Yelena Nikolayeva', event='10000m walk women'),
#  athlete_and_event(athlete='Jevaughn Minzie', event='4x100m relay'),
#  athlete_and_event(athlete='Lee Barnes', event='pole vault men'),
#  athlete_and_event(athlete='Elzbieta Dunska-Krzesinska', event='long jump women'),
#  athlete_and_event(athlete='William Mills', event='10000m men'),
#  athlete_and_event(athlete='Charles L. Jenkins', event='4x400m relay men'),
#  athlete_and_event(athlete='Jozef Schmidt', event='triple jump men'),
#  athlete_and_event(athlete='Thomas Curtis', event='110m hurdles men'),
#  athlete_and_event(athlete='J. Oliver Macdonald', event='4x400m relay men'),
#  athlete_and_event(athlete='Kevin Curtis Young', event='400m hurdles men'),
#  athlete_and_event(athlete='Ilke Wyludda', event='discus throw women'),
#  athlete_and_event(athlete='Vladimir Golubnichy', event='20km walk men'),
#  athlete_and_event(athlete='Armin Hary', event='4x100m relay men'),
#  athlete_and_event(athlete='Krisztian Pars', event='hammer throw men'),
#  athlete_and_event(athlete='Fani Chalkia', event='400m hurdles women'),
#  athlete_and_event(athlete='Hayes Jones', event='110m hurdles men'),
#  athlete_and_event(athlete='Donald James Thompson', event='50km walk men'),
#  athlete_and_event(athlete='Michael Marsh', event='4x100m relay men'),
#  athlete_and_event(athlete='Karl De Witt Warner', event='4x400m relay men'),
#  athlete_and_event(athlete='Mohamed Farah', event='5000m team'),
#  athlete_and_event(athlete='Robert Allan Kiesel', event='4x100m relay men'),
#  athlete_and_event(athlete='Frederick Schule', event='110m hurdles men'),
#  athlete_and_event(athlete='Irina Nazarova', event='4x400m relay women'),
#  athlete_and_event(athlete='Gil Roberts', event='4x400m relay'),
#  athlete_and_event(athlete='Robert Morton Newburgh Tisdall', event='400m hurdles men'),
#  athlete_and_event(athlete='Elena Isinbaeva', event='pole vault women'),
#  athlete_and_event(athlete='Jeremiah Alfred Leconey', event='4x100m relay men'),
#  athlete_and_event(athlete='Marina Chmonina', event='4x400m relay women'),
#  athlete_and_event(athlete='Jason Rouser', event='4x400m relay men'),
#  athlete_and_event(athlete='Madeline Manning-Jackson', event='800m women'),
#  athlete_and_event(athlete='William Waring Miller', event='pole vault men'),
#  athlete_and_event(athlete='Helen Herring Stephens', event='4x100m relay women'),
#  athlete_and_event(athlete='Nourredine Morceli', event='1500m men'),
#  athlete_and_event(athlete='Janusz Kusocinski', event='10000m men'),
#  athlete_and_event(athlete='Edward F. Lindberg', event='4x400m relay men'),
#  athlete_and_event(athlete='Richmond Landon', event='high jump men'),
#  athlete_and_event(athlete='Rosemarie Witschas-Ackermann', event='high jump women'),
#  athlete_and_event(athlete='Alvin Kraenzlein', event='110m hurdles men'),
#  athlete_and_event(athlete='Mary Peters', event='pentathlon women'),
#  athlete_and_event(athlete='Johanna Schaller-Klier', event='100m hurdles women'),
#  athlete_and_event(athlete='Liping Wang', event='20km race walk women'),
#  athlete_and_event(athlete='Anna Chicherova', event='high jump women'),
#  athlete_and_event(athlete='Allyson Felix', event='4x400m relay'),
#  athlete_and_event(athlete='Archie Hahn', event='200m men'),
#  athlete_and_event(athlete='Vyacheslav Ivanenko', event='50km walk men'),
#  athlete_and_event(athlete='Jürgen Schult', event='discus throw men'),
#  athlete_and_event(athlete='Steve Lewis', event='4x400m relay men'),
#  athlete_and_event(athlete='Luigi Beccali', event='1500m men'),
#  athlete_and_event(athlete='Horace Hallock Brown', event='3000m team men'),
#  athlete_and_event(athlete='Volker Beck', event='400m hurdles men'),
#  athlete_and_event(athlete='Siegrun Siegl', event='pentathlon women'),
#  athlete_and_event(athlete='Kerron Clement', event='400m hurdles'),
#  athlete_and_event(athlete='Ronald James Brown', event='4x100m relay men'),
#  athlete_and_event(athlete='Vebjorn Rodal', event='800m men'),
#  athlete_and_event(athlete='Armas Rudolf Taipale', event='discus throw men'),
#  athlete_and_event(athlete='Louis Woodard III Jones', event='4x400m relay men'),
#  athlete_and_event(athlete='James Lightbody', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Harry Hillman', event='400m hurdles men'),
#  athlete_and_event(athlete='Albin Oskar Stenroos', event='marathon men'),
#  athlete_and_event(athlete='Lasse Viren', event='10000m men'),
#  athlete_and_event(athlete='Usain Bolt', event='4x100m relay men'),
#  athlete_and_event(athlete='Mathew Birir', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Nina Romashkova-Ponomareva', event='discus throw women'),
#  athlete_and_event(athlete='Irving Baxter', event='pole vault men'),
#  athlete_and_event(athlete='Allyson Felix', event='200m women'),
#  athlete_and_event(athlete='Alvin Kraenzlein', event='200m hurdles men'),
#  athlete_and_event(athlete='Louis Alfred Clarke', event='4x100m relay men'),
#  athlete_and_event(athlete='William Applegarth', event='4x100m relay men'),
#  athlete_and_event(athlete='Derek Drouin', event='high jump'),
#  athlete_and_event(athlete='Alberto Cova', event='10000m men'),
#  athlete_and_event(athlete='Peter Rono', event='1500m men'),
#  athlete_and_event(athlete='Otis Crandall Davis', event='4x400m relay men'),
#  athlete_and_event(athlete='Gezahegne Abera', event='marathon men'),
#  athlete_and_event(athlete='Anthony William Winter', event='triple jump men'),
#  athlete_and_event(athlete='Jozef Pribilinec', event='20km walk men'),
#  athlete_and_event(athlete='George J. Jr. Saling', event='110m hurdles men'),
#  athlete_and_event(athlete='Joseph Barthel', event='1500m men'),
#  athlete_and_event(athlete='Emil Zatopek', event='marathon men'),
#  athlete_and_event(athlete='Usain Bolt', event='100m men'),
#  athlete_and_event(athlete='Stanislawa Walasiewicz', event='100m women'),
#  athlete_and_event(athlete='Felix Sanchez', event='400m hurdles men'),
#  athlete_and_event(athlete='Charles Edward Borah', event='4x100m relay men'),
#  athlete_and_event(athlete='Olga Fikotova-Connolly', event='discus throw women'),
#  athlete_and_event(athlete='Arthur Russell', event='3200m steeplechase men'),
#  athlete_and_event(athlete='Daniel Bautista rocha', event='20km walk men'),
#  athlete_and_event(athlete='Pierre Quinon', event='pole vault men'),
#  athlete_and_event(athlete='Thomas Hampson', event='800m men'),
#  athlete_and_event(athlete='Otis Harris', event='4x400m relay men'),
#  athlete_and_event(athlete='Ingrid Becker-Mickler', event='4x100m relay women'),
#  athlete_and_event(athlete='Valerie Ann Brisco-Hooks', event='400m women'),
#  athlete_and_event(athlete='Harold Norwood Ewell', event='4x100m relay men'),
#  athlete_and_event(athlete='Timoty J. Ahearne', event='triple jump men'),
#  athlete_and_event(athlete='Robert Keyser Schul', event='5000m men'),
#  athlete_and_event(athlete='Richard Sheldon', event='shot put men'),
#  athlete_and_event(athlete='Edward Lansing Gordon', event='long jump men'),
#  athlete_and_event(athlete='Tatyana Lysenko', event='hammer throw women'),
#  athlete_and_event(athlete='Rudolf Bauer', event='discus throw men'),
#  athlete_and_event(athlete='Nadezhda Chizhova', event='shot put women'),
#  athlete_and_event(athlete='John Walker', event='1500m men'),
#  athlete_and_event(athlete='Aleksandr Aksinin', event='4x100m relay men'),
#  athlete_and_event(athlete='Rochelle Stevens', event='4x400m relay women'),
#  athlete_and_event(athlete='Jeannette Josephina Maria Witziers-Timmer', event='4x100m relay women'),
#  athlete_and_event(athlete='Cyrus C. Jr. Young', event='javelin throw men'),
#  athlete_and_event(athlete='Arto Harkonen', event='javelin throw men'),
#  athlete_and_event(athlete='Taoufik Makhloufi', event='1500m men'),
#  athlete_and_event(athlete='Tore Sjöstrand', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Gabriela Szabo', event='5000m women'),
#  athlete_and_event(athlete='Lee Calhoun', event='110m hurdles men'),
#  athlete_and_event(athlete='Robert Hayes', event='4x100m relay men'),
#  athlete_and_event(athlete='Frans Wilhelmi Pörhölä', event='shot put men'),
#  athlete_and_event(athlete='Albert Lovejoy Gutterson', event='long jump men'),
#  athlete_and_event(athlete='Helge Andreas Lövland', event='decathlon men'),
#  athlete_and_event(athlete='Yulia Gushchina', event='4x100m relay women'),
#  athlete_and_event(athlete='Jean Shiley', event='high jump women'),
#  athlete_and_event(athlete='Rolf Danneberg', event='discus throw men'),
#  athlete_and_event(athlete='Ethel Catherwood', event='high jump women'),
#  athlete_and_event(athlete='Olga Shishigina', event='100m hurdles women'),
#  athlete_and_event(athlete='Eddie Tolan', event='100m men'),
#  athlete_and_event(athlete='James Randel Matson', event='shot put men'),
#  athlete_and_event(athlete='Romuald Klim', event='hammer throw men'),
#  athlete_and_event(athlete="Patrick O'callaghan", event='hammer throw men'),
#  athlete_and_event(athlete='Virgilijus Alekna', event='discus throw men'),
#  athlete_and_event(athlete='Yuliya Chermoshanskaya', event='4x100m relay women'),
#  athlete_and_event(athlete='Quincy Watts', event='4x400m relay men'),
#  athlete_and_event(athlete='Eldice Lewis', event='4x100m relay women'),
#  athlete_and_event(athlete='Stefano Baldini', event='marathon men'),
#  athlete_and_event(athlete='Alfredrick Alphonzo Joyner', event='triple jump men'),
#  athlete_and_event(athlete='Jeanette Bolden', event='4x100m relay women'),
#  athlete_and_event(athlete='Alvin Harrison', event='4x400m relay men'),
#  athlete_and_event(athlete='Valerie Ann Brisco-Hooks', event='4x400m relay women'),
#  athlete_and_event(athlete='Ewa Klobukowska', event='4x100m relay women'),
#  athlete_and_event(athlete='Said Aouita', event='5000m men'),
#  athlete_and_event(athlete='Cathy Freeman', event='400m women'),
#  athlete_and_event(athlete='Romas Ubartas', event='discus throw men'),
#  athlete_and_event(athlete='Valeriy Borchin', event='20km walk men'),
#  athlete_and_event(athlete='Murray Gordon Halberg', event='5000m men'),
#  athlete_and_event(athlete='Nick Hysong', event='pole vault men'),
#  athlete_and_event(athlete='Renate Stecher', event='200m women'),
#  athlete_and_event(athlete='Halina Konopacka', event='discus throw women'),
#  athlete_and_event(athlete='Sara Simeoni', event='high jump women'),
#  athlete_and_event(athlete='Kipchoge Keino', event='1500m men'),
#  athlete_and_event(athlete='Olga Bondarenko', event='10000m women'),
#  athlete_and_event(athlete='Dieter Baumann', event='5000m men'),
#  athlete_and_event(athlete='Martina Hellmann', event='discus throw women'),
#  athlete_and_event(athlete='Charles Joseph Bacon', event='400m hurdles men'),
#  athlete_and_event(athlete='Florence Griffith-Joyner', event='4x100m relay women'),
#  athlete_and_event(athlete='Khalid Skah', event='10000m men'),
#  athlete_and_event(athlete='Esther Cornelia Brand', event='high jump women'),
#  athlete_and_event(athlete='Gwen Torrence', event='200m women'),
#  athlete_and_event(athlete='Melvin Jr. Pender', event='4x100m relay men'),
#  athlete_and_event(athlete='William Tanui', event='800m men'),
#  athlete_and_event(athlete='Harry Stoddard Babcock', event='pole vault men'),
#  athlete_and_event(athlete='Edgar Allen Ablowich', event='4x400m relay men'),
#  athlete_and_event(athlete='Emil Zatopek', event='5000m men'),
#  athlete_and_event(athlete='Forrest Smithson', event='110m hurdles men'),
#  athlete_and_event(athlete='Arnie Robinson', event='long jump men'),
#  athlete_and_event(athlete='Frederik Teudor Koskenniemi', event='cross country team men'),
#  athlete_and_event(athlete='Ilona Schoknecht-Slupianek', event='shot put women'),
#  athlete_and_event(athlete='Irving Baxter', event='high jump men'),
#  athlete_and_event(athlete='Sidney Robinson', event='5000m team men'),
#  athlete_and_event(athlete='Viorica Viscopoleanu', event='long jump women'),
#  athlete_and_event(athlete='Andrea Anderson', event='4x400m relay women'),
#  athlete_and_event(athlete='Zhen Wang', event='20km walk'),
#  athlete_and_event(athlete='Maksim Tarasov', event='pole vault men'),
#  athlete_and_event(athlete='Steve Ovett', event='800m men'),
#  athlete_and_event(athlete='Deborah Flintoff-King', event='400m hurdles women'),
#  athlete_and_event(athlete='Veronica Campbell-Brown', event='200m women'),
#  athlete_and_event(athlete='Bernd Cullmann', event='4x100m relay men'),
#  athlete_and_event(athlete='Hezekiah Munyoro Nyamau', event='4x400m relay men'),
#  athlete_and_event(athlete='William De Hart Hubbard', event='long jump men'),
#  athlete_and_event(athlete='Monique Hennagan', event='4x400m relay women'),
#  athlete_and_event(athlete='Shelly-Ann Fraser', event='100m women'),
#  athlete_and_event(athlete='Wilfred Bungei', event='800m men'),
#  athlete_and_event(athlete='George Orton', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Tatiana Prorochenko', event='4x400m relay women'),
#  athlete_and_event(athlete='Denise Lewis', event='heptathlon women'),
#  athlete_and_event(athlete='Thomas William Courtney', event='4x400m relay men'),
#  athlete_and_event(athlete='Mohamed Gammoudi', event='5000m men'),
#  athlete_and_event(athlete='Lilia Nurutdinova', event='4x400m relay women'),
#  athlete_and_event(athlete='Vladimir Kuts', event='5000m men'),
#  athlete_and_event(athlete='Andrew William Stanfield', event='4x100m relay men'),
#  athlete_and_event(athlete='Peter Snell', event='1500m men'),
#  athlete_and_event(athlete='Maurice Greene', event='100m men'),
#  athlete_and_event(athlete='Michael Mathieu', event='4x400m relay men'),
#  athlete_and_event(athlete='Carolina Kluft', event='heptathlon women'),
#  athlete_and_event(athlete='Alistair Brownlee', event='triathlon (long jump / shot put / 100 yards)'),
#  athlete_and_event(athlete='Gisela Mauermayer', event='discus throw women'),
#  athlete_and_event(athlete='Edith Marie Mcguire', event='200m women'),
#  athlete_and_event(athlete='Viktor Markin', event='4x400m relay men'),
#  athlete_and_event(athlete='Yueling Chen', event='10000m walk women'),
#  athlete_and_event(athlete='Robert Richards', event='pole vault men'),
#  athlete_and_event(athlete='Teresa Barbara Wieczorek-Cieply', event='4x100m relay women'),
#  athlete_and_event(athlete='Duncan Mcnaughton', event='high jump men'),
#  athlete_and_event(athlete='Valery Borzov', event='200m men'),
#  athlete_and_event(athlete='Hassiba Boulmerka', event='1500m women'),
#  athlete_and_event(athlete='Bianca Knight', event='4x100m relay women'),
#  athlete_and_event(athlete='Betty Cuthbert', event='100m women'),
#  athlete_and_event(athlete='Sandra Perkovic', event='discus throw'),
#  athlete_and_event(athlete='John H. Kuck', event='shot put men'),
#  athlete_and_event(athlete='Moushaumi Robinson', event='4x400m relay women'),
#  athlete_and_event(athlete='Frederick Ferdinand Wolff', event='4x400m relay men'),
#  athlete_and_event(athlete='James Connolly', event='triple jump men'),
#  athlete_and_event(athlete='Richard Douglas Fosbury', event='high jump men'),
#  athlete_and_event(athlete='Balazs Kiss', event='hammer throw men'),
#  athlete_and_event(athlete='Nataliia Dobrynska', event='heptathlon women'),
#  athlete_and_event(athlete='Jozsef Csermak', event='hammer throw men'),
#  athlete_and_event(athlete='Marlon Devonish', event='4x100m relay men'),
#  athlete_and_event(athlete='Hasely Crawford', event='100m men'),
#  athlete_and_event(athlete='Robert Ouko', event='4x400m relay men'),
#  athlete_and_event(athlete='Ralph Craig', event='200m men'),
#  athlete_and_event(athlete='Tianna Bartoletta', event='long jump'),
#  athlete_and_event(athlete='Daley Thompson', event='decathlon men'),
#  athlete_and_event(athlete='Haile Gebrselassie', event='10000m men'),
#  athlete_and_event(athlete='John Jesus Flanagan', event='hammer throw men'),
#  athlete_and_event(athlete='Ville Ritola', event='10000m men'),
#  athlete_and_event(athlete='Earl Verdelle Young', event='4x400m relay men'),
#  athlete_and_event(athlete='Xenia Stad-De jong', event='4x100m relay women'),
#  athlete_and_event(athlete='Ulrike Meyfarth', event='high jump women'),
#  athlete_and_event(athlete='Quincy Watts', event='400m men'),
#  athlete_and_event(athlete='Sally Janet Jane Gunnell', event='400m hurdles women'),
#  athlete_and_event(athlete='Chandra Sturrup', event='4x100m relay women'),
#  athlete_and_event(athlete='Ronald Ray Smith', event='4x100m relay men'),
#  athlete_and_event(athlete='Robert Kerr', event='200m men'),
#  athlete_and_event(athlete='Tony Mcquay', event='4x400m relay'),
#  athlete_and_event(athlete='Catherine Hardy', event='4x100m relay women'),
#  athlete_and_event(athlete='Nouria Merah-Benida', event='1500m women'),
#  athlete_and_event(athlete='Inese Yaunzeme', event='javelin throw women'),
#  athlete_and_event(athlete='Emil Zatopek', event='10000m men'),
#  athlete_and_event(athlete='Galina Zybina', event='shot put women'),
#  athlete_and_event(athlete='Mo Farah', event='10miles walk (16093m) men'),
#  athlete_and_event(athlete='DeeDee Trotter', event='4x400m relay women'),
#  athlete_and_event(athlete='Nabiba Naftali Temu', event='10000m men'),
#  athlete_and_event(athlete='Lia Manoliu', event='discus throw women'),
#  athlete_and_event(athlete='Tereza Marinova', event='triple jump women'),
#  athlete_and_event(athlete='Szymon Ziolkowski', event='hammer throw men'),
#  athlete_and_event(athlete='Barbora Spotakova', event='javelin throw women'),
#  athlete_and_event(athlete='Shelly-Ann Fraser-Pryce', event='100m women'),
#  athlete_and_event(athlete='Tianna Madison', event='4x100m relay women'),
#  athlete_and_event(athlete='Edward James Hart', event='4x100m relay men'),
#  athlete_and_event(athlete='Javier Sotomayor', event='high jump men'),
#  athlete_and_event(athlete='Keshorn Walcott', event='javelin throw men'),
#  athlete_and_event(athlete='Walter Mahlendorf', event='4x100m relay men'),
#  athlete_and_event(athlete='Zdzislaw Krzyszkowiak', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Valentina Yegorova', event='marathon women'),
#  athlete_and_event(athlete='Greg Rutherford', event='long jump men'),
#  athlete_and_event(athlete='John Artur Ljunggren', event='50km walk men'),
#  athlete_and_event(athlete='Svetlana Masterkova', event='1500m women'),
#  athlete_and_event(athlete='Angelo Taylor', event='4x400m relay men'),
#  athlete_and_event(athlete='Vladimir Kuts', event='10000m men'),
#  athlete_and_event(athlete='Lemuel Clarence Houser', event='discus throw men'),
#  athlete_and_event(athlete='Irena Szewinska', event='4x100m relay women'),
#  athlete_and_event(athlete='Edwin Flack', event='800m men'),
#  athlete_and_event(athlete='Melvin Sheppard', event='800m men'),
#  athlete_and_event(athlete='Patrick Ryan', event='hammer throw men'),
#  athlete_and_event(athlete='Betty Cuthbert', event='400m women'),
#  athlete_and_event(athlete='Usain Bolt', event='200m'),
#  athlete_and_event(athlete='Martha B. Hudson', event='4x100m relay women'),
#  athlete_and_event(athlete='Fluer Northey Mellor-Wenham', event='4x100m relay women'),
#  athlete_and_event(athlete='Alice Regina Brown', event='4x100m relay women'),
#  athlete_and_event(athlete='Ivan William Fuqua', event='4x400m relay men'),
#  athlete_and_event(athlete='Irving Jahir Saladino aranda', event='long jump men'),
#  athlete_and_event(athlete='Robert Alexander Lindsay', event='4x400m relay men'),
#  athlete_and_event(athlete='Timothy Mack', event='pole vault men'),
#  athlete_and_event(athlete='Frederick Vaughn Newhouse', event='4x400m relay men'),
#  athlete_and_event(athlete='Joseph Edmund Deakin', event='3miles team (4828m) men'),
#  athlete_and_event(athlete='Delfo Cabrera', event='marathon men'),
#  athlete_and_event(athlete='Maria Colon', event='javelin throw women'),
#  athlete_and_event(athlete='Tori Bowie', event='4x100m relay'),
#  athlete_and_event(athlete='Sanya Richards', event='4x400m relay women'),
#  athlete_and_event(athlete='Dwight Phillips', event='long jump men'),
#  athlete_and_event(athlete='Tatiana Ledovskaya', event='4x400m relay women'),
#  athlete_and_event(athlete='Junxia Wang', event='5000m women'),
#  athlete_and_event(athlete='Yuriy Borzakovskiy', event='800m men'),
#  athlete_and_event(athlete='Cornelius Cooper Johnson', event='high jump men'),
#  athlete_and_event(athlete='Owen Guinn Smith', event='pole vault men'),
#  athlete_and_event(athlete='Vera Kolashnikova-Krepkina', event='long jump women'),
#  athlete_and_event(athlete='Robert Shavlakadze', event='high jump men'),
#  athlete_and_event(athlete='Ivanka Mikailova Christova-Todorova', event='shot put women'),
#  athlete_and_event(athlete='Nina Ziuskova', event='4x400m relay women'),
#  athlete_and_event(athlete='Jennifer Suhr', event='pole vault women'),
#  athlete_and_event(athlete='Edward Tiffin Cooke', event='pole vault men'),
#  athlete_and_event(athlete="Dan O'brien", event='decathlon men'),
#  athlete_and_event(athlete='Constantina Tomescu', event='marathon women'),
#  athlete_and_event(athlete='Vivian Jepkemoi Cheruiyot', event='5000m team'),
#  athlete_and_event(athlete='Juan Carlos Zabala', event='marathon men'),
#  athlete_and_event(athlete='James Aloysius Bernard Bausch', event='decathlon men'),
#  athlete_and_event(athlete='Olga Nazarova', event='4x400m relay women'),
#  athlete_and_event(athlete='Kipchoge Keino', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Bärbel Eckert-Wöckel', event='4x100m relay women'),
#  athlete_and_event(athlete='Pauline Elaine Davis', event='4x100m relay women'),
#  athlete_and_event(athlete='Ralph Rose', event='shot put men'),
#  athlete_and_event(athlete='Alfred Tysoe', event='800m men'),
#  athlete_and_event(athlete='Glenn Ashby Davis', event='400m hurdles men'),
#  athlete_and_event(athlete='Matthew J. Mcgrath', event='hammer throw men'),
#  athlete_and_event(athlete='Hannes Kolehmainen', event='marathon men'),
#  athlete_and_event(athlete='Robert Mathias', event='decathlon men'),
#  athlete_and_event(athlete='Marita Koch', event='400m women'),
#  athlete_and_event(athlete='Willi Holdorf', event='decathlon men'),
#  athlete_and_event(athlete='Crystal Cox', event='4x400m relay women'),
#  athlete_and_event(athlete='Raymond Armstead', event='4x400m relay men'),
#  athlete_and_event(athlete='Robert Wade King', event='high jump men'),
#  athlete_and_event(athlete='Max Emmerich', event='triathlon (long jump / shot put / 100 yards) men'),
#  athlete_and_event(athlete='Hjalmar Andersson', event='cross country team men'),
#  athlete_and_event(athlete='Charles Lamont Jenkins', event='4x400m relay men'),
#  athlete_and_event(athlete='Yohan Blake', event='4x100m relay'),
#  athlete_and_event(athlete='Demetrius Pinder', event='4x400m relay men'),
#  athlete_and_event(athlete='Ray Ewry', event='high jump, standing men'),
#  athlete_and_event(athlete='Gelindo Bordin', event='marathon men'),
#  athlete_and_event(athlete='John Lovelock', event='1500m men'),
#  athlete_and_event(athlete='John Nathaniel Cartmell', event='4x400m relay men'),
#  athlete_and_event(athlete='Lynn Davies', event='long jump men'),
#  athlete_and_event(athlete='Andrew Valmon', event='4x400m relay men'),
#  athlete_and_event(athlete='Steven Earl Riddick', event='4x100m relay men'),
#  athlete_and_event(athlete='Pyotr Bolotnikov', event='10000m men'),
#  athlete_and_event(athlete='Jessica Ennis', event='heptathlon'),
#  athlete_and_event(athlete='Angela Nemeth-Ranky', event='javelin throw women'),
#  athlete_and_event(athlete='Robert Joseph Morrow', event='4x100m relay men'),
#  athlete_and_event(athlete='Tia Hellebaut', event='high jump women'),
#  athlete_and_event(athlete='Bronislaw Malinowski', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Julius Korir', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Jerome Cousins Biffle', event='long jump men'),
#  athlete_and_event(athlete='Norman Taber', event='3000m team men'),
#  athlete_and_event(athlete='John Creyghton Ainsworth-Davis', event='4x400m relay men'),
#  athlete_and_event(athlete='Charles Bennett', event='5000m team men'),
#  athlete_and_event(athlete='Pauli Lauri Nevala', event='javelin throw men'),
#  athlete_and_event(athlete='Jemima Jelagat Sumgong', event='marathon'),
#  athlete_and_event(athlete='Lemuel Clarence Houser', event='shot put men'),
#  athlete_and_event(athlete='S. Talja', event='3000m team men'),
#  athlete_and_event(athlete='Anisoara Cusmir-Stanciu', event='long jump women'),
#  athlete_and_event(athlete='William Roberts', event='4x400m relay men'),
#  athlete_and_event(athlete='Kenenisa Bekele', event='5000m men'),
#  athlete_and_event(athlete='Mildred Louise Mcdaniel', event='high jump women'),
#  athlete_and_event(athlete='Doris Maletzki', event='4x400m relay women'),
#  athlete_and_event(athlete='Stefan Holm', event='high jump men'),
#  athlete_and_event(athlete='Almaz Ayana', event='10miles walk (16093m)'),
#  athlete_and_event(athlete='Tatiana Kolpakova', event='long jump women'),
#  athlete_and_event(athlete='William Kenneth Carpenter', event='discus throw men'),
#  athlete_and_event(athlete='Hannes Kolehmainen', event='10000m men'),
#  athlete_and_event(athlete='Melvin Sheppard', event='4x400m relay men'),
#  athlete_and_event(athlete='Edwin Moses', event='400m hurdles men'),
#  athlete_and_event(athlete='Sherryl Frances Howard', event='4x400m relay women'),
#  athlete_and_event(athlete='Charles Decker Reidpath', event='4x400m relay men'),
#  athlete_and_event(athlete='Hermine (Herma) Bauma', event='javelin throw women'),
#  athlete_and_event(athlete='Walter B. John Tewksbury', event='200m men'),
#  athlete_and_event(athlete='Calvin Smith', event='4x100m relay men'),
#  athlete_and_event(athlete='Marie-Jose Perec', event='400m women'),
#  athlete_and_event(athlete='Tiki Gelana', event='marathon women'),
#  athlete_and_event(athlete='John Lloyd Yerman', event='4x400m relay men'),
#  athlete_and_event(athlete='Livio Berruti', event='200m men'),
#  athlete_and_event(athlete='Wyomia Tyus', event='100m women'),
#  athlete_and_event(athlete='Leamon King', event='4x100m relay men'),
#  athlete_and_event(athlete='Miloslava Rezkova-Hubner', event='high jump women'),
#  athlete_and_event(athlete='James Jett', event='4x100m relay men'),
#  athlete_and_event(athlete='Karoline "Lina" Radke', event='800m women'),
#  athlete_and_event(athlete='Dawn Harper', event='100m hurdles women'),
#  athlete_and_event(athlete='Pamela Jelimo', event='800m women'),
#  athlete_and_event(athlete='Wolfgang Nordwig', event='pole vault men'),
#  athlete_and_event(athlete='Wilhelmina Von bremen', event='4x100m relay women'),
#  athlete_and_event(athlete='Mildred Didrikson', event='80m hurdles women'),
#  athlete_and_event(athlete='Edwin Flack', event='1500m men'),
#  athlete_and_event(athlete='Melvin Sheppard', event='1500m men'),
#  athlete_and_event(athlete='Samuel Kamau Wansiru', event='marathon men'),
#  athlete_and_event(athlete='Shirley Strickland-De La Hunty', event='4x100m relay women'),
#  athlete_and_event(athlete='Thomas William Green', event='50km walk men'),
#  athlete_and_event(athlete='Millard Frank Jr. Hampton', event='4x100m relay men'),
#  athlete_and_event(athlete='Anier Garcia', event='110m hurdles men'),
#  athlete_and_event(athlete='Konstantinos Kenteris', event='200m men'),
# ...
#  athlete_and_event(athlete='Ibolya Csak', event='high jump women'),
#  athlete_and_event(athlete='Robert Korzeniowski', event='20km walk men'),
#  athlete_and_event(athlete='Richard Vaughn Stebbins', event='4x100m relay men'),
#  athlete_and_event(athlete='Robert Zmelik', event='decathlon men'),
#  athlete_and_event(athlete='Guy Montagu Butler', event='4x400m relay men'),
#  athlete_and_event(athlete='Gyula Zsivotzky', event='hammer throw men'),
#  athlete_and_event(athlete='Diamond Dixon', event='4x400m relay women'),
#  athlete_and_event(athlete='Kim Graham', event='4x400m relay women'),
#  athlete_and_event(athlete='Kenneth Joseph Matthews', event='20km walk men'),
#  athlete_and_event(athlete='Joseph Guillemot', event='5000m men'),
#  athlete_and_event(athlete='Alberto Juantorena', event='400m men'),
#  athlete_and_event(athlete='Sabin William Carr', event='pole vault men'),
#  athlete_and_event(athlete='Rafer Lewis Johnson', event='decathlon men'),
#  athlete_and_event(athlete='Caterine Ibarguen', event='triple jump'),
#  athlete_and_event(athlete='Ivan Ukhov', event='high jump men'),
#  athlete_and_event(athlete='Michael Frater', event='4x100m relay men'),
#  athlete_and_event(athlete='Brian Lewis', event='4x100m relay men'),
#  athlete_and_event(athlete='Melvin Emery Patton', event='200m men'),
#  athlete_and_event(athlete='Courtney Okolo', event='4x400m relay'),
#  athlete_and_event(athlete='Mildrette Netter', event='4x100m relay women'),
#  athlete_and_event(athlete='Carlton Chambers', event='4x100m relay men'),
#  athlete_and_event(athlete='Harry Franklin Porter', event='high jump men'),
#  athlete_and_event(athlete='Carl Lewis', event='long jump men'),
#  athlete_and_event(athlete='Harry Hillman', event='400m men'),
#  athlete_and_event(athlete='Tomasz Majewski', event='shot put men'),
#  athlete_and_event(athlete='Arthur Wint', event='4x400m relay men'),
#  athlete_and_event(athlete='Mihaela Penes', event='javelin throw women'),
#  athlete_and_event(athlete='Monique Henderson', event='4x400m relay women'),
#  athlete_and_event(athlete='Brittney Reese', event='long jump women'),
#  athlete_and_event(athlete='Ellina Zvereva', event='discus throw women'),
#  athlete_and_event(athlete='Asbel Kipruto Kiprop', event='1500m men'),
#  athlete_and_event(athlete='Gustav Lindblom', event='triple jump men'),
#  athlete_and_event(athlete='Inger Miller', event='4x100m relay women'),
#  athlete_and_event(athlete='Kenny Harrison', event='triple jump men'),
#  athlete_and_event(athlete='Jacek Wszola', event='high jump men'),
#  athlete_and_event(athlete='Liudmila Kondratieva', event='100m women'),
#  athlete_and_event(athlete='Alonzo C. Babers', event='4x400m relay men'),
#  athlete_and_event(athlete='Otis Paul Drayton', event='4x100m relay men'),
#  athlete_and_event(athlete='Olga Rypakova', event='triple jump women'),
#  athlete_and_event(athlete='Sergey Bubka', event='pole vault men'),
#  athlete_and_event(athlete='Pekka Vasala', event='1500m men'),
#  athlete_and_event(athlete='Harold Vincent Connolly', event='hammer throw men'),
#  athlete_and_event(athlete='Venuste Niyongabo', event='5000m men'),
#  athlete_and_event(athlete='Elmer Konstantin Niklander', event='discus throw men'),
#  athlete_and_event(athlete='Eero Berg', event='cross country team men'),
#  athlete_and_event(athlete='Roy Braxton Cochran', event='400m hurdles men'),
#  athlete_and_event(athlete='Robert Garrett', event='shot put men'),
#  athlete_and_event(athlete='Angelo Taylor', event='400m hurdles men'),
#  athlete_and_event(athlete='Mariya Pinigina', event='4x400m relay women'),
#  athlete_and_event(athlete='James F. Quinn', event='4x100m relay men'),
#  athlete_and_event(athlete='Allen Woodring', event='200m men'),
#  athlete_and_event(athlete='Michelle Finn', event='4x100m relay women'),
#  athlete_and_event(athlete='Meseret Defar', event='5000m team women'),
#  athlete_and_event(athlete='Alvin Kraenzlein', event='60m men'),
#  athlete_and_event(athlete='Margaret Johnson Bailes', event='4x100m relay women'),
#  athlete_and_event(athlete='Janet Theresa Moreau', event='4x100m relay women'),
#  athlete_and_event(athlete='Nikolai Avilov', event='decathlon men'),
#  athlete_and_event(athlete='Herman Ronald Frazier', event='4x400m relay men'),
#  athlete_and_event(athlete='Barbara Pearl Jones', event='4x100m relay women'),
#  athlete_and_event(athlete='Frank Loomis', event='400m hurdles men'),
#  athlete_and_event(athlete='Fanny Blankers-Koen', event='80m hurdles women'),
#  athlete_and_event(athlete='Lucinda Williams', event='4x100m relay women'),
#  athlete_and_event(athlete='Harold Marion Osborn', event='decathlon men'),
#  athlete_and_event(athlete='Valerie Ann Brisco-Hooks', event='200m women'),
#  athlete_and_event(athlete='Ethel M. Smith', event='4x100m relay women'),
#  athlete_and_event(athlete='Iryna Press', event='80m hurdles women'),
#  athlete_and_event(athlete='Sebastian Coe', event='1500m men'),
#  athlete_and_event(athlete='Hugo K. Wieslander', event='decathlon men'),
#  athlete_and_event(athlete='Konstantinos Tsiclitiras', event='long jump, standing men'),
#  athlete_and_event(athlete='Udo Beyer', event='shot put men'),
#  athlete_and_event(athlete='Yaak Uudmae', event='triple jump men'),
#  athlete_and_event(athlete='Tanya Lawrence', event='4x100m relay women'),
#  athlete_and_event(athlete='Stephen Kiprotich', event='marathon men'),
#  athlete_and_event(athlete='Kemar Bailey-Cole', event='4x100m relay men'),
#  athlete_and_event(athlete='Ville Ritola', event='3000m team men'),
#  athlete_and_event(athlete='Waldemar Cierpinski', event='marathon men'),
#  athlete_and_event(athlete='Morolake Akinosun', event='4x100m relay'),
#  athlete_and_event(athlete='Bärbel Eckert-Wöckel', event='200m women'),
#  athlete_and_event(athlete='Eric Lemming', event='javelin throw freestyle men'),
#  athlete_and_event(athlete='Raul Gonzalez', event='50km walk men'),
#  athlete_and_event(athlete='Matti Henrik Jarvinen', event='javelin throw men'),
#  athlete_and_event(athlete='Francis Jarvis', event='100m men'),
#  athlete_and_event(athlete='James Lightbody', event='800m men'),
#  athlete_and_event(athlete='Derrick Adkins', event='400m hurdles men'),
#  athlete_and_event(athlete='Jefferson Perez', event='20km walk men'),
#  athlete_and_event(athlete='Paavo Nurmi', event='3000m team men'),
#  athlete_and_event(athlete='Yvette Winefred Williams', event='long jump women'),
#  athlete_and_event(athlete='Brianna Rollins', event='100m hurdles'),
#  athlete_and_event(athlete='Arthur Harold Harnden', event='4x400m relay men'),
#  athlete_and_event(athlete='Carl Lewis', event='4x100m relay men'),
#  athlete_and_event(athlete='Adhemar Ferreira Da Silva', event='triple jump men'),
#  athlete_and_event(athlete='Jim Thorpe', event='decathlon men'),
#  athlete_and_event(athlete='Albert Hill', event='800m men'),
#  athlete_and_event(athlete='Kenenisa Bekele', event='10000m men'),
#  athlete_and_event(athlete='Mo Farah', event='5000m team men'),
#  athlete_and_event(athlete='Emil Robert Voigt', event='5 miles (8047m) men'),
#  athlete_and_event(athlete='Eino Seppälä', event='3000m team men'),
#  athlete_and_event(athlete='Mamo Wolde', event='marathon men'),
#  athlete_and_event(athlete='Christiane Krause', event='4x100m relay women'),
#  athlete_and_event(athlete='Olga Bryzgina', event='400m women'),
#  athlete_and_event(athlete='Renate Stecher', event='4x100m relay women'),
#  athlete_and_event(athlete='Evelin Schlaak-Jahl', event='discus throw women'),
#  athlete_and_event(athlete='William Arthur Carr', event='400m men'),
#  athlete_and_event(athlete='Naoto Tajima', event='triple jump men'),
#  athlete_and_event(athlete='Trebisonda Valla', event='80m hurdles women'),
#  athlete_and_event(athlete='William Arthur Carr', event='4x400m relay men'),
#  athlete_and_event(athlete='Anders Garderud', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Lee Edward Evans', event='400m men'),
#  athlete_and_event(athlete='Julius Kariuki', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Jackson Scholz', event='200m men'),
#  athlete_and_event(athlete='Stacy Dragila', event='pole vault women'),
#  athlete_and_event(athlete='Lindy Remigino', event='100m men'),
#  athlete_and_event(athlete='Gerhard (Gerd) Stöck', event='javelin throw men'),
#  athlete_and_event(athlete='Natasha Hastings', event='4x400m relay'),
#  athlete_and_event(athlete='Fermin Cacho ruiz', event='1500m men'),
#  athlete_and_event(athlete='Jackie Joyner-Kersee', event='heptathlon women'),
#  athlete_and_event(athlete='Donovan Bailey', event='100m men'),
#  athlete_and_event(athlete='Lyudmila Bragina', event='1500m women'),
#  athlete_and_event(athlete='Elizabeth Robinson', event='4x100m relay women'),
#  athlete_and_event(athlete='Patrick Mcdonald', event='shot put men'),
#  athlete_and_event(athlete='Milton Gray Campbell', event='decathlon men'),
#  athlete_and_event(athlete='Tadeusz Slusarski', event='pole vault men'),
#  athlete_and_event(athlete='Miruts Yifter', event='10000m men'),
#  athlete_and_event(athlete='Paavo Nurmi', event='5000m men'),
#  athlete_and_event(athlete='Gunnar Höckert', event='5000m men'),
#  athlete_and_event(athlete='Irena Szewinska', event='400m women'),
#  athlete_and_event(athlete='Thomas Francis Kiely', event='decathlon men'),
#  athlete_and_event(athlete='Nadezhda Tkachenko', event='pentathlon women'),
#  athlete_and_event(athlete='Veronica Campbell-Brown', event='4x100m relay women'),
#  athlete_and_event(athlete='John Akii-Bua', event='400m hurdles men'),
#  athlete_and_event(athlete='Elaine Thompson', event='100m'),
#  athlete_and_event(athlete='Simeon Garland Iness', event='discus throw men'),
#  athlete_and_event(athlete='Dilshod Nazarov', event='hammer throw'),
#  athlete_and_event(athlete='Boughera Mohamed El Ouafi', event='marathon men'),
#  athlete_and_event(athlete='Lauri Aleksanteri Lehtinen', event='5000m men'),
#  athlete_and_event(athlete='Donovan Bailey', event='4x100m relay men'),
#  athlete_and_event(athlete='Malvin Groston Whitfield', event='800m men'),
#  athlete_and_event(athlete='Andrey Abduvaliev', event='hammer throw men'),
#  athlete_and_event(athlete='Mae Heriwentha Faggs', event='4x100m relay women'),
#  athlete_and_event(athlete='Sandra Perkovic', event='discus throw women'),
#  athlete_and_event(athlete='English Gardner', event='4x100m relay'),
#  athlete_and_event(athlete='Morris Kirksey', event='4x100m relay men'),
#  athlete_and_event(athlete='Cecil Richmond Griffiths', event='4x400m relay men'),
#  athlete_and_event(athlete='Andrey Silnov', event='high jump men'),
#  athlete_and_event(athlete='Thomas Hicks', event='marathon men'),
#  athlete_and_event(athlete='Gabriella Dorio', event='1500m women'),
#  athlete_and_event(athlete='Meyer Prinstein', event='long jump men'),
#  athlete_and_event(athlete='Nikolai Chernetski', event='4x400m relay men'),
#  athlete_and_event(athlete='William Anthony Toomey', event='decathlon men'),
#  athlete_and_event(athlete='Charles Asati', event='4x400m relay men'),
#  athlete_and_event(athlete='Carla Bodendorf', event='4x100m relay women'),
#  athlete_and_event(athlete='Jon Drummond', event='4x100m relay men'),
#  athlete_and_event(athlete='Xiang Liu', event='110m hurdles men'),
#  athlete_and_event(athlete='Michelle Carter', event='shot put'),
#  athlete_and_event(athlete='Usain Bolt', event='4x100m relay'),
#  athlete_and_event(athlete='Gregory Curtis Bell', event='long jump men'),
#  athlete_and_event(athlete='Alessandro Andrei', event='shot put men'),
#  athlete_and_event(athlete='Vladimir Krylov', event='4x100m relay men'),
#  athlete_and_event(athlete='Robert Taylor', event='4x100m relay men'),
#  athlete_and_event(athlete='Ezekiel Kemboi', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Stanley Rowley', event='5000m team men'),
#  athlete_and_event(athlete='Nelson Evora', event='triple jump men'),
#  athlete_and_event(athlete='David Verburg', event='4x400m relay'),
#  athlete_and_event(athlete='Abel Kiviat', event='3000m team men'),
#  athlete_and_event(athlete='Wilbur Marvin Thompson', event='shot put men'),
#  athlete_and_event(athlete='Heidemarie Rosendahl', event='4x100m relay women'),
#  athlete_and_event(athlete='Eino Rastas', event='cross country team men'),
#  athlete_and_event(athlete='Eric Lemming', event='javelin throw men'),
#  athlete_and_event(athlete='Jean Thompson', event='4x100m relay women'),
#  athlete_and_event(athlete='Antonio Ricardo Mckay', event='4x400m relay men'),
#  athlete_and_event(athlete='Harry Butch . Reynolds', event='4x400m relay men'),
#  athlete_and_event(athlete='Emerson Lane Spencer', event='4x400m relay men'),
#  athlete_and_event(athlete='Mary Wineberg', event='4x400m relay women'),
#  athlete_and_event(athlete='Aries Merritt', event='110m hurdles men'),
#  athlete_and_event(athlete='Jesse Owens', event='100m men'),
#  athlete_and_event(athlete='Harvey Edward Glance', event='4x100m relay men'),
#  athlete_and_event(athlete='Abdon Pamich', event='50km walk men'),
#  athlete_and_event(athlete='Julius Sang', event='4x400m relay men'),
#  athlete_and_event(athlete='Dennis Mitchell', event='4x100m relay men'),
#  athlete_and_event(athlete='Meseret Defar', event='5000m women'),
#  athlete_and_event(athlete='Norma Wilson Crooker-Fleming', event='4x100m relay women'),
#  athlete_and_event(athlete='Kelly Holmes', event='800m women'),
#  athlete_and_event(athlete='Mike Conley', event='triple jump men'),
#  athlete_and_event(athlete='LaShawn Merritt', event='4x400m relay men'),
#  athlete_and_event(athlete='Alfred Carleten Gilbert', event='pole vault men'),
#  athlete_and_event(athlete='Frederick Pitt Alderman', event='4x400m relay men'),
#  athlete_and_event(athlete='Alonzo C. Babers', event='400m men'),
#  athlete_and_event(athlete='Chandra Danette Cheeseborough', event='4x100m relay women'),
#  athlete_and_event(athlete='Dallas Crutcher III Long', event='shot put men'),
#  athlete_and_event(athlete='Tianna Bartoletta', event='4x100m relay'),
#  athlete_and_event(athlete='Frederick Morgan Taylor', event='400m hurdles men'),
#  athlete_and_event(athlete='Harry Hillman', event='200m hurdles men'),
#  athlete_and_event(athlete='Brimin Kiprop Kipruto', event='3000m steeplechase men'),
#  athlete_and_event(athlete='Ralph Doubell', event='800m men'),
#  athlete_and_event(athlete='Alfred Oerter', event='discus throw men'),
#  athlete_and_event(athlete='Jesse Owens', event='4x100m relay men'),
#  athlete_and_event(athlete='Donald Quarrie', event='200m men'),
#  athlete_and_event(athlete='Jonni Myyrä', event='javelin throw men'),
#  athlete_and_event(athlete='Tirunesh Dibaba', event='10miles walk (16093m) women'),
#  athlete_and_event(athlete='Vitaly Savin', event='4x100m relay men'),
#  athlete_and_event(athlete='Eddie Tolan', event='200m men'),
#  athlete_and_event(athlete='Ollan Conley Cassell', event='4x400m relay men'),
#  athlete_and_event(athlete='Gerald A. Tinker', event='4x100m relay men'),
#  athlete_and_event(athlete='Fernanda Ribeiro', event='10000m women'),
#  athlete_and_event(athlete='Derartu Tulu', event='10000m women'),
#  athlete_and_event(athlete='Michael Johnson', event='200m men'),
#  athlete_and_event(athlete='Samuel Jones', event='high jump men'),
#  athlete_and_event(athlete='Väinö Jeremias Sipilä', event='cross country team men'),
#  athlete_and_event(athlete='Kelly Holmes', event='1500m women'),
#  athlete_and_event(athlete='Kristo Gantchev Markov', event='triple jump men'),
#  athlete_and_event(athlete='Olga Kaniskina', event='20km race walk women'),
#  athlete_and_event(athlete='LaTasha Colander', event='4x400m relay women'),
#  athlete_and_event(athlete='Mohamed Farah', event='10miles walk (16093m)'),
#  athlete_and_event(athlete='Lorenzo Christopher Wright', event='4x100m relay men'),
#  athlete_and_event(athlete='Lindy Remigino', event='4x100m relay men'),
#  athlete_and_event(athlete='Charles Everett Dumas', event='high jump men'),
#  athlete_and_event(athlete='Bob Beamon', event='long jump men'),
#  athlete_and_event(athlete='Darnell Hall', event='4x400m relay men'),
#  athlete_and_event(athlete='Francena Mccorory', event='4x400m relay'),
#  athlete_and_event(athlete='Fatuma Roba', event='marathon women'),
#  athlete_and_event(athlete='Wilma Rudolph', event='4x100m relay women'),
#  ...}

# %%
counter = collections.Counter(athlete_and_event.athlete for athlete_and_event in athletes_and_events)

# %%
counter.most_common(5)
# Out:
# [('Usain Bolt', 6),
#  ('Paavo Nurmi', 6),
#  ('Ville Ritola', 5),
#  ('Allyson Felix', 5),
#  ('Fanny Blankers-Koen', 4)]

# %% [markdown]
# ##### Correct solution for Q2

# %%
events_by_athlete_set = collections.defaultdict(set)

# %%
def clean(event):
    return ' '.join(word for word in event.split() if word not in ('men', 'women'))

# %%
for medal in medals:
    events_by_athlete_set[medal.athlete].add(clean(medal.event))

# %%
def count_events(events_tuple):
    return len(events_tuple[1])

sorted(events_by_athlete_set.items(), key = count_events, reverse = True)
# Out:
# [('Paavo Nurmi',
#   {'10000m',
#    '1500m',
#    '3000m team',
#    '5000m',
#    'cross country individual',
#    'cross country team'}),
#  ('Ville Ritola',
#   {'10000m',
#    '3000m steeplechase',
#    '3000m team',
#    '5000m',
#    'cross country team'}),
#  ('Alvin Kraenzlein', {'110m hurdles', '200m hurdles', '60m', 'long jump'}),
#  ('Hannes Kolehmainen',
#   {'10000m', '5000m', 'cross country individual', 'marathon'}),
#  ('Jesse Owens', {'100m', '200m', '4x100m relay', 'long jump'}),
#  ('Fanny Blankers-Koen', {'100m', '200m', '4x100m relay', '80m hurdles'}),
#  ('Betty Cuthbert', {'100m', '200m', '400m', '4x100m relay'}),
#  ('Carl Lewis', {'100m', '200m', '4x100m relay', 'long jump'}),
#  ('Ray Ewry',
#   {'high jump, standing', 'long jump, standing', 'triple jump, standing'}),
#  ('Archie Hahn', {'100m', '200m', '60m'}),
#  ('James Lightbody', {'1500m', '3000m steeplechase', '800m'}),
#  ('Harry Hillman', {'200m hurdles', '400m', '400m hurdles'}),
#  ('Melvin Sheppard', {'1500m', '4x400m relay', '800m'}),
#  ('Emil Zatopek', {'10000m', '5000m', 'marathon'}),
#  ('Harrison Dillard', {'100m', '110m hurdles', '4x100m relay'}),
#  ('Robert Joseph Morrow', {'100m', '200m', '4x100m relay'}),
#  ('Wilma Rudolph', {'100m', '200m', '4x100m relay'}),
#  ('Irena Szewinska', {'200m', '400m', '4x100m relay'}),
#  ('Renate Stecher', {'100m', '200m', '4x100m relay'}),
#  ('Valerie Ann Brisco-Hooks', {'200m', '400m', '4x400m relay'}),
#  ('Florence Griffith-Joyner', {'100m', '200m', '4x100m relay'}),
#  ('Michael Johnson', {'200m', '400m', '4x400m relay'}),
#  ('Tirunesh Dibaba', {'10000m', '10miles walk (16093m)', '5000m'}),
#  ('Usain Bolt', {'100m', '200m', '4x100m relay'}),
#  ('Allyson Felix', {'200m', '4x100m relay', '4x400m relay'}),
#  ('Thomas Burke', {'100m', '400m'}),
#  ('Edwin Flack', {'1500m', '800m'}),
#  ('Robert Garrett', {'discus throw', 'shot put'}),
#  ('Ellery Clark', {'high jump', 'long jump'}),
#  ('Charles Bennett', {'1500m', '5000m team'}),
#  ('Walter B. John Tewksbury', {'200m', '400m hurdles'}),
#  ('John Rimmer', {'4000m steeplechase', '5000m team'}),
#  ('Alfred Tysoe', {'5000m team', '800m'}),
#  ('Irving Baxter', {'high jump', 'pole vault'}),
#  ('Meyer Prinstein', {'long jump', 'triple jump'}),
#  ('Martin Sheridan', {'discus throw', 'discus throw ancient style'}),
#  ('Ralph Rose', {'shot put', 'shot put, both hands'}),
#  ('George Edward Larner', {'10miles walk (16093m)', '3500m walk'}),
#  ('Eric Lemming', {'javelin throw', 'javelin throw freestyle'}),
#  ('Ralph Craig', {'100m', '200m'}),
#  ('Charles Decker Reidpath', {'400m', '4x400m relay'}),
#  ('James Edwin Meredith', {'4x400m relay', '800m'}),
#  ('Jim Thorpe', {'decathlon', 'pentathlon'}),
#  ('Armas Rudolf Taipale', {'discus throw', 'discus throw, both hands'}),
#  ('Patrick Mcdonald', {'56lb weight throw (25.4kg)', 'shot put'}),
#  ('Ugo Frigerio', {'10000m walk', '3000m walk'}),
#  ('Charles Paddock', {'100m', '4x100m relay'}),
#  ('Albert Hill', {'1500m', '800m'}),
#  ('Jackson Scholz', {'200m', '4x100m relay'}),
#  ('Harold Marion Osborn', {'decathlon', 'high jump'}),
#  ('Lemuel Clarence Houser', {'discus throw', 'shot put'}),
#  ('Percy Williams', {'100m', '200m'}),
#  ('Elizabeth Robinson', {'100m', '4x100m relay'}),
#  ('Raymond James Barbuti', {'400m', '4x400m relay'}),
#  ('Eddie Tolan', {'100m', '200m'}),
#  ('William Arthur Carr', {'400m', '4x400m relay'}),
#  ('Mildred Didrikson', {'80m hurdles', 'javelin throw'}),
#  ('Helen Herring Stephens', {'100m', '4x100m relay'}),
#  ('Melvin Emery Patton', {'200m', '4x100m relay'}),
#  ('Arthur Wint', {'400m', '4x400m relay'}),
#  ('Roy Braxton Cochran', {'400m hurdles', '4x400m relay'}),
#  ('Malvin Groston Whitfield', {'4x400m relay', '800m'}),
#  ('Micheline Ostermeyer', {'discus throw', 'shot put'}),
#  ('Lindy Remigino', {'100m', '4x100m relay'}),
#  ('Marjorie Jackson', {'100m', '200m'}),
#  ('Andrew William Stanfield', {'200m', '4x100m relay'}),
#  ('Vincent George Rhoden', {'400m', '4x400m relay'}),
#  ('Shirley Strickland-De La Hunty', {'4x100m relay', '80m hurdles'}),
#  ('Vladimir Kuts', {'10000m', '5000m'}),
#  ('Charles Lamont Jenkins', {'400m', '4x400m relay'}),
#  ('Glenn Ashby Davis', {'400m hurdles', '4x400m relay'}),
#  ('Thomas William Courtney', {'4x400m relay', '800m'}),
#  ('Armin Hary', {'100m', '4x100m relay'}),
#  ('Otis Crandall Davis', {'400m', '4x400m relay'}),
#  ('Peter Snell', {'1500m', '800m'}),
#  ('Iryna Press', {'80m hurdles', 'pentathlon'}),
#  ('Tamara Press', {'discus throw', 'shot put'}),
#  ('Robert Hayes', {'100m', '4x100m relay'}),
#  ('Wyomia Tyus', {'100m', '4x100m relay'}),
#  ('Henry Carr', {'200m', '4x400m relay'}),
#  ('Michael Denny Larrabee', {'400m', '4x400m relay'}),
#  ('James Ray Hines', {'100m', '4x100m relay'}),
#  ('Kipchoge Keino', {'1500m', '3000m steeplechase'}),
#  ('Lee Edward Evans', {'400m', '4x400m relay'}),
#  ('Vincent Edward Matthews', {'400m', '4x400m relay'}),
#  ('Ingrid Becker-Mickler', {'4x100m relay', 'pentathlon'}),
#  ('Lasse Viren', {'10000m', '5000m'}),
#  ('Valery Borzov', {'100m', '200m'}),
#  ('Monika Zehrt', {'400m', '4x400m relay'}),
#  ('Annegret Richter-Irrgang', {'100m', '4x100m relay'}),
#  ('Heidemarie Rosendahl', {'4x100m relay', 'long jump'}),
#  ('Tatiana Kazankina', {'1500m', '800m'}),
#  ('Bärbel Eckert-Wöckel', {'200m', '4x100m relay'}),
#  ('Alberto Juantorena', {'400m', '800m'}),
#  ('Miruts Yifter', {'10000m', '5000m'}),
#  ('Viktor Markin', {'400m', '4x400m relay'}),
#  ('Evelyn Ashford', {'100m', '4x100m relay'}),
#  ('Alonzo C. Babers', {'400m', '4x400m relay'}),
#  ('Chandra Danette Cheeseborough', {'4x100m relay', '4x400m relay'}),
#  ('Steve Lewis', {'400m', '4x400m relay'}),
#  ('Olga Bryzgina', {'400m', '4x400m relay'}),
#  ('Jackie Joyner-Kersee', {'heptathlon', 'long jump'}),
#  ('Gail Devers', {'100m', '4x100m relay'}),
#  ('Michael Marsh', {'200m', '4x100m relay'}),
#  ('Gwen Torrence', {'200m', '4x100m relay'}),
#  ('Quincy Watts', {'400m', '4x400m relay'}),
#  ('Marie-Jose Perec', {'200m', '400m'}),
#  ('Donovan Bailey', {'100m', '4x100m relay'}),
#  ('Svetlana Masterkova', {'1500m', '800m'}),
#  ('Robert Korzeniowski', {'20km walk', '50km walk'}),
#  ('Maurice Greene', {'100m', '4x100m relay'}),
#  ('Pauline Elaine Davis', {'200m', '4x100m relay'}),
#  ('Angelo Taylor', {'400m hurdles', '4x400m relay'}),
#  ('Kenenisa Bekele', {'10000m', '5000m'}),
#  ('Hicham El guerrouj', {'1500m', '5000m'}),
#  ('Kelly Holmes', {'1500m', '800m'}),
#  ('Veronica Campbell-Brown', {'200m', '4x100m relay'}),
#  ('Jeremy Wariner', {'400m', '4x400m relay'}),
#  ('Meseret Defar', {'5000m', '5000m team'}),
#  ('LaShawn Merritt', {'400m', '4x400m relay'}),
#  ('Sanya Richards-Ross', {'400m', '4x400m relay'}),
#  ('Mo Farah', {'10miles walk (16093m)', '5000m team'}),
#  ('Elaine Thompson', {'100m', '200m'}),
#  ('Tianna Bartoletta', {'4x100m relay', 'long jump'}),
#  ('Mohamed Farah', {'10miles walk (16093m)', '5000m team'}),
#  ('Thomas Curtis', {'110m hurdles'}),
#  ('Spyridon Louis', {'marathon'}),
#  ('William Welles Hoyt', {'pole vault'}),
#  ('James Connolly', {'triple jump'}),
#  ('Francis Jarvis', {'100m'}),
#  ('George Orton', {'3000m steeplechase'}),
#  ('Maxwell W.Maxey Long', {'400m'}),
#  ('Sidney Robinson', {'5000m team'}),
#  ('Stanley Rowley', {'5000m team'}),
#  ('Rudolf Bauer', {'discus throw'}),
#  ('John Jesus Flanagan', {'hammer throw'}),
#  ('Michel Theato', {'marathon'}),
#  ('Richard Sheldon', {'shot put'}),
#  ('Frederick Schule', {'110m hurdles'}),
#  ('David Curtis Munson', {'4miles team'}),
#  ('Arthur Newton', {'4miles team'}),
#  ('Paul Harry Pilgrim', {'4miles team'}),
#  ('George Underwood', {'4miles team'}),
#  ('Howard Valentine', {'4miles team'}),
#  ('Etienne Desmarteau', {'56lb weight throw (25.4kg)'}),
#  ('Thomas Francis Kiely', {'decathlon'}),
#  ('Samuel Jones', {'high jump'}),
#  ('Thomas Hicks', {'marathon'}),
#  ('Charles Dvorak', {'pole vault'}),
#  ('Max Emmerich', {'triathlon (long jump / shot put / 100 yards)'}),
#  ('Reginald Walker', {'100m'}),
#  ('Forrest Smithson', {'110m hurdles'}),
#  ('Robert Kerr', {'200m'}),
#  ('Arthur Russell', {'3200m steeplechase'}),
#  ('William Coales', {'3miles team (4828m)'}),
#  ('Joseph Edmund Deakin', {'3miles team (4828m)'}),
#  ('Arthur James Robertson', {'3miles team (4828m)'}),
#  ('Wyndham Halswelle', {'400m'}),
#  ('Charles Joseph Bacon', {'400m hurdles'}),
#  ('John Nathaniel Cartmell', {'4x400m relay'}),
#  ('William Frank Hamilton', {'4x400m relay'}),
#  ('John Baxter Taylor', {'4x400m relay'}),
#  ('Emil Robert Voigt', {'5 miles (8047m)'}),
#  ('Harry Franklin Porter', {'high jump'}),
#  ('Francis C. Irons', {'long jump'}),
#  ('John Joseph Hayes', {'marathon'}),
#  ('Edward Tiffin Cooke', {'pole vault'}),
#  ('Alfred Carleten Gilbert', {'pole vault'}),
#  ('Timoty J. Ahearne', {'triple jump'}),
#  ('George Goulding', {'10000m walk'}),
#  ('Frederick Kelly', {'110m hurdles'}),
#  ('Arnold Jackson', {'1500m'}),
#  ('Tell Schirnding Berna', {'3000m team'}),
#  ('George V. Bonhag', {'3000m team'}),
#  ('Abel Kiviat', {'3000m team'}),
#  ('Henry Louis Scott', {'3000m team'}),
#  ('Norman Taber', {'3000m team'}),
#  ('William Applegarth', {'4x100m relay'}),
#  ("Victor Henry Augustus D'arcy", {'4x100m relay'}),
#  ('David Henry Jacobs', {'4x100m relay'}),
#  ('Henry Maitland Mackintosh', {'4x100m relay'}),
#  ('Edward F. Lindberg', {'4x400m relay'}),
#  ('Hjalmar Andersson', {'cross country team'}),
#  ('John Eke', {'cross country team'}),
#  ('Josef Ternström', {'cross country team'}),
#  ('Hugo K. Wieslander', {'decathlon'}),
#  ('Matthew J. Mcgrath', {'hammer throw'}),
#  ('Alma Wilfred Richards', {'high jump'}),
#  ('Platt Adams', {'high jump, standing'}),
#  ('Juho Julius Saaristo', {'javelin throw, both hands'}),
#  ('Albert Lovejoy Gutterson', {'long jump'}),
#  ('Konstantinos Tsiclitiras', {'long jump, standing'}),
#  ('Kennedy Kane Mcarthur', {'marathon'}),
#  ('Ferdinand Reinhardt Bie', {'pentathlon'}),
#  ('Harry Stoddard Babcock', {'pole vault'}),
#  ('Gustav Lindblom', {'triple jump'}),
#  ('Earl Thomson', {'110m hurdles'}),
#  ('Allen Woodring', {'200m'}),
#  ('Percy Hodge', {'3000m steeplechase'}),
#  ('Horace Hallock Brown', {'3000m team'}),
#  ('Ivan Dresser', {'3000m team'}),
#  ('Arlie Alfred Schardt', {'3000m team'}),
#  ("Bevil Gordon D'Urban Rudd", {'400m'}),
#  ('Frank Loomis', {'400m hurdles'}),
#  ('Morris Kirksey', {'4x100m relay'}),
#  ('Loren Murchison', {'4x100m relay'}),
#  ('John Creyghton Ainsworth-Davis', {'4x400m relay'}),
#  ('Guy Montagu Butler', {'4x400m relay'}),
#  ('Cecil Richmond Griffiths', {'4x400m relay'}),
#  ('Robert Alexander Lindsay', {'4x400m relay'}),
#  ('Joseph Guillemot', {'5000m'}),
#  ('Frederik Teudor Koskenniemi', {'cross country team'}),
#  ('Heikki Liimatainen', {'cross country team'}),
#  ('Helge Andreas Lövland', {'decathlon'}),
#  ('Elmer Konstantin Niklander', {'discus throw'}),
#  ('Patrick Ryan', {'hammer throw'}),
#  ('Richmond Landon', {'high jump'}),
#  ('Jonni Myyrä', {'javelin throw'}),
#  ('R. William E. Petersson', {'long jump'}),
#  ('Eero Reino Lehtonen', {'pentathlon'}),
#  ('Frank Foss', {'pole vault'}),
#  ('Frans Wilhelmi Pörhölä', {'shot put'}),
#  ('Vilho Immanuel Tuulos', {'triple jump'}),
#  ('Harold Abrahams', {'100m'}),
#  ('Daniel Kinsey', {'110m hurdles'}),
#  ('Elias Katz', {'3000m team'}),
#  ('Frej Liewendhal', {'3000m team'}),
#  ('Eino Seppälä', {'3000m team'}),
#  ('S. Talja', {'3000m team'}),
#  ('Eric Henry Liddell', {'400m'}),
#  ('Frederick Morgan Taylor', {'400m hurdles'}),
#  ('Louis Alfred Clarke', {'4x100m relay'}),
#  ('Francis Hussey', {'4x100m relay'}),
#  ('Jeremiah Alfred Leconey', {'4x100m relay'}),
#  ('Commodore Cochrane', {'4x400m relay'}),
#  ('Alan Helffrich', {'4x400m relay'}),
#  ('J. Oliver Macdonald', {'4x400m relay'}),
#  ('William Stephenson', {'4x400m relay'}),
#  ('Douglas Gordon Lowe', {'800m'}),
#  ('Eero Berg', {'cross country team'}),
#  ('Eino Rastas', {'cross country team'}),
#  ('Väinö Jeremias Sipilä', {'cross country team'}),
#  ('Frederick Delmont Tootell', {'hammer throw'}),
#  ('William De Hart Hubbard', {'long jump'}),
#  ('Albin Oskar Stenroos', {'marathon'}),
#  ('Lee Barnes', {'pole vault'}),
#  ('Anthony William Winter', {'triple jump'}),
#  ('Sidney Atkinson', {'110m hurdles'}),
#  ('Harri Edvin Larva', {'1500m'}),
#  ('Toivo Aarne Loukola', {'3000m steeplechase'}),
#  ('David George Burghley', {'400m hurdles'}),
#  ('Charles Edward Borah', {'4x100m relay'}),
#  ('James F. Quinn', {'4x100m relay'}),
#  ('Henry Argue Russell', {'4x100m relay'}),
#  ('Frank Clifford Wykoff', {'4x100m relay'}),
#  ('Myrtle Alice Cook', {'4x100m relay'}),
#  ('Fanny Rosenfeld', {'4x100m relay'}),
#  ('Ethel M. Smith', {'4x100m relay'}),
#  ('Jean Thompson', {'4x100m relay'}),
#  ('Frederick Pitt Alderman', {'4x400m relay'}),
#  ('George Hetzel Baird', {'4x400m relay'}),
#  ('Emerson Lane Spencer', {'4x400m relay'}),
#  ('Karoline "Lina" Radke', {'800m'}),
#  ('Paavo Ilmari Yrjölä', {'decathlon'}),
#  ('Halina Konopacka', {'discus throw'}),
#  ("Patrick O'callaghan", {'hammer throw'}),
#  ('Robert Wade King', {'high jump'}),
#  ('Ethel Catherwood', {'high jump'}),
#  ('Erik H. Lundqvist', {'javelin throw'}),
#  ('Edward Barton Hamm', {'long jump'}),
#  ('Boughera Mohamed El Ouafi', {'marathon'}),
#  ('Sabin William Carr', {'pole vault'}),
#  ('John H. Kuck', {'shot put'}),
#  ('Mikio Oda', {'triple jump'}),
#  ('Janusz Kusocinski', {'10000m'}),
#  ('Stanislawa Walasiewicz', {'100m'}),
#  ('George J. Jr. Saling', {'110m hurdles'}),
#  ('Luigi Beccali', {'1500m'}),
#  ('Volmari Iso-Hollo', {'3000m steeplechase'}),
#  ('Robert Morton Newburgh Tisdall', {'400m hurdles'}),
#  ('Hector Monroe Dyer', {'4x100m relay'}),
#  ('Robert Allan Kiesel', {'4x100m relay'}),
#  ('Martin Emmett Toppino', {'4x100m relay'}),
#  ('Mary Louise Carew', {'4x100m relay'}),
#  ('Evelyn Furtsch', {'4x100m relay'}),
#  ('Annette Joan Rogers', {'4x100m relay'}),
#  ('Wilhelmina Von bremen', {'4x100m relay'}),
#  ('Edgar Allen Ablowich', {'4x400m relay'}),
#  ('Ivan William Fuqua', {'4x400m relay'}),
#  ('Karl De Witt Warner', {'4x400m relay'}),
#  ('Lauri Aleksanteri Lehtinen', {'5000m'}),
#  ('Thomas William Green', {'50km walk'}),
#  ('Thomas Hampson', {'800m'}),
#  ('James Aloysius Bernard Bausch', {'decathlon'}),
#  ('John Franklin Anderson', {'discus throw'}),
#  ('Lillian Copeland', {'discus throw'}),
#  ('Duncan Mcnaughton', {'high jump'}),
#  ('Jean Shiley', {'high jump'}),
#  ('Matti Henrik Jarvinen', {'javelin throw'}),
#  ('Edward Lansing Gordon', {'long jump'}),
#  ('Juan Carlos Zabala', {'marathon'}),
#  ('William Waring Miller', {'pole vault'}),
#  ('Leo Joseph Sexton', {'shot put'}),
#  ('Chuhei Nambu', {'triple jump'}),
#  ('Ilmari Salminen', {'10000m'}),
#  ('Forrest Grady Towns', {'110m hurdles'}),
#  ('John Lovelock', {'1500m'}),
#  ('Archibald Franklin Williams', {'400m'}),
#  ('Glenn Foster Hardin', {'400m hurdles'}),
#  ('Foy Draper', {'4x100m relay'}),
#  ('Ralph Metcalfe', {'4x100m relay'}),
#  ('Harriett Claiborne Bland', {'4x100m relay'}),
#  ('Arthur Godfrey Kilner Brown', {'4x400m relay'}),
#  ('Godfrey Lionel Rampling', {'4x400m relay'}),
#  ('William Roberts', {'4x400m relay'}),
#  ('Frederick Ferdinand Wolff', {'4x400m relay'}),
#  ('Gunnar Höckert', {'5000m'}),
#  ('Hector Harold Whitlock', {'50km walk'}),
#  ('John Youie Woodruff', {'800m'}),
#  ('Trebisonda Valla', {'80m hurdles'}),
#  ('Glenn Edward Morris', {'decathlon'}),
#  ('William Kenneth Carpenter', {'discus throw'}),
#  ('Gisela Mauermayer', {'discus throw'}),
#  ('Karl Hein', {'hammer throw'}),
#  ('Cornelius Cooper Johnson', {'high jump'}),
#  ('Ibolya Csak', {'high jump'}),
#  ('Gerhard (Gerd) Stöck', {'javelin throw'}),
#  ('Mathilde (Tilly) Fleischer', {'javelin throw'}),
#  ('Kitei Son', {'marathon'}),
#  ('Earle Elmer Meadows', {'pole vault'}),
#  ('Hans Woellke', {'shot put'}),
#  ('Naoto Tajima', {'triple jump'}),
#  ('John Mikaelsson', {'10000m walk'}),
#  ('William Franklin III Porter', {'110m hurdles'}),
#  ('Henry Eriksson', {'1500m'}),
#  ('Tore Sjöstrand', {'3000m steeplechase'}),
#  ('Harold Norwood Ewell', {'4x100m relay'}),
#  ('Lorenzo Christopher Wright', {'4x100m relay'}),
#  ('Xenia Stad-De jong', {'4x100m relay'}),
#  ('Gerda Johanna Marie Van der kade-Koudijs', {'4x100m relay'}),
#  ('Jeannette Josephina Maria Witziers-Timmer', {'4x100m relay'}),
#  ('Clifford Frederick Bourland', {'4x400m relay'}),
#  ('Arthur Harold Harnden', {'4x400m relay'}),
#  ('Gaston Etienne Reiff', {'5000m'}),
#  ('John Artur Ljunggren', {'50km walk'}),
#  ('Robert Mathias', {'decathlon'}),
#  ('Adolfo Consolini', {'discus throw'}),
#  ('Imre Nemeth', {'hammer throw'}),
#  ('John Winter', {'high jump'}),
#  ('Alice Marie Coachman', {'high jump'}),
#  ('Kaj Tapio Rautavaara', {'javelin throw'}),
#  ('Hermine (Herma) Bauma', {'javelin throw'}),
#  ('William Samuel Steele', {'long jump'}),
#  ('Olga Gyarmati', {'long jump'}),
#  ('Delfo Cabrera', {'marathon'}),
#  ('Owen Guinn Smith', {'pole vault'}),
#  ('Wilbur Marvin Thompson', {'shot put'}),
#  ('Arne Ahman', {'triple jump'}),
#  ('Joseph Barthel', {'1500m'}),
#  ('Horace III Ashenfelter', {'3000m steeplechase'}),
#  ('Charles Hewes Jr. Moore', {'400m hurdles'}),
#  ('Finis Dean Smith', {'4x100m relay'}),
#  ('Mae Heriwentha Faggs', {'4x100m relay'}),
#  ('Catherine Hardy', {'4x100m relay'}),
#  ('Barbara Pearl Jones', {'4x100m relay'}),
#  ('Janet Theresa Moreau', {'4x100m relay'}),
#  ('Leslie Laing', {'4x400m relay'}),
#  ('Herbert Mckenley', {'4x400m relay'}),
#  ('Giuseppe Dordoni', {'50km walk'}),
#  ('Simeon Garland Iness', {'discus throw'}),
#  ('Nina Romashkova-Ponomareva', {'discus throw'}),
#  ('Jozsef Csermak', {'hammer throw'}),
#  ('Walter Francis Davis', {'high jump'}),
#  ('Esther Cornelia Brand', {'high jump'}),
#  ('Cyrus C. Jr. Young', {'javelin throw'}),
#  ('Dana Ingrova-Zatopkova', {'javelin throw'}),
#  ('Jerome Cousins Biffle', {'long jump'}),
#  ('Yvette Winefred Williams', {'long jump'}),
#  ('Robert Richards', {'pole vault'}),
#  ('William Patrick Jr. O', {'shot put'}),
#  ('Galina Zybina', {'shot put'}),
#  ('Adhemar Ferreira Da Silva', {'triple jump'}),
#  ('Lee Calhoun', {'110m hurdles'}),
#  ('Ronald Michael Delany', {'1500m'}),
#  ('Leonid Spirin', {'20km walk'}),
#  ('Christopher William Brasher', {'3000m steeplechase'}),
#  ('Walter Thane Baker', {'4x100m relay'}),
#  ('Leamon King', {'4x100m relay'}),
#  ('Ira James Murchison', {'4x100m relay'}),
#  ('Norma Wilson Crooker-Fleming', {'4x100m relay'}),
#  ('Fluer Northey Mellor-Wenham', {'4x100m relay'}),
#  ('Louis Woodard III Jones', {'4x400m relay'}),
#  ('Jesse William Mashburn', {'4x400m relay'}),
#  ('Norman Richard Read', {'50km walk'}),
#  ('Milton Gray Campbell', {'decathlon'}),
#  ('Alfred Oerter', {'discus throw'}),
#  ('Olga Fikotova-Connolly', {'discus throw'}),
#  ('Harold Vincent Connolly', {'hammer throw'}),
#  ('Charles Everett Dumas', {'high jump'}),
#  ('Mildred Louise Mcdaniel', {'high jump'}),
#  ('Egil Danielsen', {'javelin throw'}),
#  ('Inese Yaunzeme', {'javelin throw'}),
#  ('Gregory Curtis Bell', {'long jump'}),
#  ('Elzbieta Dunska-Krzesinska', {'long jump'}),
#  ('Alain Mimoun', {'marathon'}),
#  ('Tamara Tyshkevich', {'shot put'}),
#  ('Pyotr Bolotnikov', {'10000m'}),
#  ('Herbert Elliott', {'1500m'}),
#  ('Livio Berruti', {'200m'}),
#  ('Vladimir Golubnichy', {'20km walk'}),
#  ('Zdzislaw Krzyszkowiak', {'3000m steeplechase'}),
#  ('Bernd Cullmann', {'4x100m relay'}),
#  ('Martin Lauer', {'4x100m relay'}),
#  ('Walter Mahlendorf', {'4x100m relay'}),
#  ('Martha B. Hudson', {'4x100m relay'}),
#  ('Lucinda Williams', {'4x100m relay'}),
#  ('John Lloyd Yerman', {'4x400m relay'}),
#  ('Earl Verdelle Young', {'4x400m relay'}),
#  ('Murray Gordon Halberg', {'5000m'}),
#  ('Donald James Thompson', {'50km walk'}),
#  ('Lyudmila Lisenko-Shevtsova', {'800m'}),
#  ('Rafer Lewis Johnson', {'decathlon'}),
#  ('Vasili Rudenkov', {'hammer throw'}),
#  ('Robert Shavlakadze', {'high jump'}),
#  ('Iolanda Balas', {'high jump'}),
#  ('Viktor Tsybulenko', {'javelin throw'}),
#  ('Elvira Ozolina', {'javelin throw'}),
#  ('Ralph Harold Boston', {'long jump'}),
#  ('Vera Kolashnikova-Krepkina', {'long jump'}),
#  ('Abebe Bikila', {'marathon'}),
#  ('Donald George Bragg', {'pole vault'}),
#  ('William Henry Nieder', {'shot put'}),
#  ('Jozef Schmidt', {'triple jump'}),
#  ('William Mills', {'10000m'}),
#  ('Hayes Jones', {'110m hurdles'}),
#  ('Edith Marie Mcguire', {'200m'}),
#  ('Kenneth Joseph Matthews', {'20km walk'}),
#  ('Gaston Roelants', {'3000m steeplechase'}),
#  ('Warren (Rex) Jay Cawley', {'400m hurdles'}),
#  ('Gerald Howard Ashworth', {'4x100m relay'}),
#  ('Otis Paul Drayton', {'4x100m relay'}),
#  ('Richard Vaughn Stebbins', {'4x100m relay'}),
#  ('Halina Herrmann-Gorecka-Richter', {'4x100m relay'}),
#  ('Ewa Klobukowska', {'4x100m relay'}),
#  ('Teresa Barbara Wieczorek-Cieply', {'4x100m relay'}),
#  ('Ollan Conley Cassell', {'4x400m relay'}),
#  ('Ulis C. Williams', {'4x400m relay'}),
#  ('Robert Keyser Schul', {'5000m'}),
#  ('Abdon Pamich', {'50km walk'}),
#  ('Ann Elizabeth Packer', {'800m'}),
#  ('Karin Richert-Balzer', {'80m hurdles'}),
#  ('Willi Holdorf', {'decathlon'}),
#  ('Romuald Klim', {'hammer throw'}),
#  ('Valeri Brumel', {'high jump'}),
#  ('Pauli Lauri Nevala', {'javelin throw'}),
#  ('Mihaela Penes', {'javelin throw'}),
#  ('Lynn Davies', {'long jump'}),
#  ('Mary Denise Bignal-Rand', {'long jump'}),
#  ('Frederick Morgan Hansen', {'pole vault'}),
#  ('Dallas Crutcher III Long', {'shot put'}),
#  ('Nabiba Naftali Temu', {'10000m'}),
#  ('Willie Davenport', {'110m hurdles'}),
#  ('Thomas C. Smith', {'200m'}),
#  ('Amos Kipwabok Biwott', {'3000m steeplechase'}),
#  ('Colette Besson', {'400m'}),
#  ('David Peter Hemery', {'400m hurdles'}),
#  ('Charles Edward Greene', {'4x100m relay'}),
#  ('Melvin Jr. Pender', {'4x100m relay'}),
#  ('Ronald Ray Smith', {'4x100m relay'}),
#  ('Margaret Johnson Bailes', {'4x100m relay'}),
#  ('Barbara Ann Ferrell', {'4x100m relay'}),
#  ('Mildrette Netter', {'4x100m relay'}),
#  ('Ronald John III Freeman', {'4x400m relay'}),
#  ('George Lawrence James', {'4x400m relay'}),
#  ('Mohamed Gammoudi', {'5000m'}),
#  ('Christoph Höhne', {'50km walk'}),
#  ('Ralph Doubell', {'800m'}),
#  ('Madeline Manning-Jackson', {'800m'}),
#  ('Maureen Caird', {'80m hurdles'}),
#  ('William Anthony Toomey', {'decathlon'}),
#  ('Lia Manoliu', {'discus throw'}),
#  ('Gyula Zsivotzky', {'hammer throw'}),
#  ('Richard Douglas Fosbury', {'high jump'}),
#  ('Miloslava Rezkova-Hubner', {'high jump'}),
#  ('Yanis Lusis', {'javelin throw'}),
#  ('Angela Nemeth-Ranky', {'javelin throw'}),
#  ('Bob Beamon', {'long jump'}),
#  ('Viorica Viscopoleanu', {'long jump'}),
#  ('Mamo Wolde', {'marathon'}),
#  ('Robert Lloyd Seagren', {'pole vault'}),
#  ('James Randel Matson', {'shot put'}),
#  ('Margitta Helmbold-Gummel', {'shot put'}),
#  ('Viktor Saneev', {'triple jump'}),
#  ('Annelie Ehrhardt', {'100m hurdles'}),
#  ('Rodney Jr. Milburn', {'110m hurdles'}),
#  ('Pekka Vasala', {'1500m'}),
#  ('Lyudmila Bragina', {'1500m'}),
#  ('Peter Frenkel', {'20km walk'}),
#  ('John Akii-Bua', {'400m hurdles'}),
#  ('Lawrence J. Black', {'4x100m relay'}),
#  ('Edward James Hart', {'4x100m relay'}),
#  ('Robert Taylor', {'4x100m relay'}),
#  ('Gerald A. Tinker', {'4x100m relay'}),
#  ('Christiane Krause', {'4x100m relay'}),
#  ('Charles Asati', {'4x400m relay'}),
#  ('Hezekiah Munyoro Nyamau', {'4x400m relay'}),
#  ('Robert Ouko', {'4x400m relay'}),
#  ('Julius Sang', {'4x400m relay'}),
#  ('Dagmar Käsling', {'4x400m relay'}),
#  ('Rita Kühne', {'4x400m relay'}),
#  ('Helga Seidler', {'4x400m relay'}),
#  ('Bernd Kannenberg', {'50km walk'}),
#  ('David James Wottle', {'800m'}),
#  ('Hildegard Falck-Janze', {'800m'}),
#  ('Nikolai Avilov', {'decathlon'}),
#  ('Ludvik Danek', {'discus throw'}),
#  ('Faina Melnik', {'discus throw'}),
#  ('Anatoli Bondarchuk', {'hammer throw'}),
#  ('Yuri Tarmak', {'high jump'}),
#  ('Ulrike Meyfarth', {'high jump'}),
#  ('Klaus Wolfermann', {'javelin throw'}),
#  ('Ruth Fuchs', {'javelin throw'}),
#  ('Randel Luvelle Williams', {'long jump'}),
#  ('Frank Charles Shorter', {'marathon'}),
#  ('Mary Peters', {'pentathlon'}),
#  ('Wolfgang Nordwig', {'pole vault'}),
#  ('Wladyslaw Komar', {'shot put'}),
#  ('Nadezhda Chizhova', {'shot put'}),
#  ('Hasely Crawford', {'100m'}),
#  ('Johanna Schaller-Klier', {'100m hurdles'}),
#  ('Guy Drut', {'110m hurdles'}),
#  ('John Walker', {'1500m'}),
#  ('Donald Quarrie', {'200m'}),
#  ('Daniel Bautista rocha', {'20km walk'}),
#  ('Anders Garderud', {'3000m steeplechase'}),
#  ('Edwin Moses', {'400m hurdles'}),
#  ('Harvey Edward Glance', {'4x100m relay'}),
#  ('Millard Frank Jr. Hampton', {'4x100m relay'}),
#  ('John Wesley Jones', {'4x100m relay'}),
#  ('Steven Earl Riddick', {'4x100m relay'}),
#  ('Carla Bodendorf', {'4x100m relay'}),
#  ('Marlies Oelsner-Göhr', {'4x100m relay'}),
#  ('Benjamin Gene Brown', {'4x400m relay'}),
#  ('Herman Ronald Frazier', {'4x400m relay'}),
#  ('Frederick Vaughn Newhouse', {'4x400m relay'}),
#  ('Maxwell Lander Parks', {'4x400m relay'}),
#  ('Christina Brehmer-Lathan', {'4x400m relay'}),
#  ('Doris Maletzki', {'4x400m relay'}),
#  ('Brigitte Rohde', {'4x400m relay'}),
#  ('Ellen Stropahl-Streidt', {'4x400m relay'}),
#  ('William Bruce Jenner', {'decathlon'}),
#  ('Malcolm Maurice Wilkins', {'discus throw'}),
#  ('Evelin Schlaak-Jahl', {'discus throw'}),
#  ('Yuri Sedykh', {'hammer throw'}),
#  ('Jacek Wszola', {'high jump'}),
#  ('Rosemarie Witschas-Ackermann', {'high jump'}),
#  ('Miklos Nemeth', {'javelin throw'}),
#  ('Arnie Robinson', {'long jump'}),
#  ('Angela Voigt', {'long jump'}),
#  ('Waldemar Cierpinski', {'marathon'}),
#  ('Siegrun Siegl', {'pentathlon'}),
#  ('Tadeusz Slusarski', {'pole vault'}),
#  ('Udo Beyer', {'shot put'}),
#  ('Ivanka Mikailova Christova-Todorova', {'shot put'}),
#  ('Allan Wells', {'100m'}),
#  ('Liudmila Kondratieva', {'100m'}),
#  ('Vera Komisova', {'100m hurdles'}),
#  ('Thomas Munkelt', {'110m hurdles'}),
#  ('Sebastian Coe', {'1500m'}),
#  ('Pietro Mennea', {'200m'}),
#  ('Maurizio Damilano', {'20km walk'}),
#  ('Bronislaw Malinowski', {'3000m steeplechase'}),
#  ('Marita Koch', {'400m'}),
#  ('Volker Beck', {'400m hurdles'}),
#  ('Aleksandr Aksinin', {'4x100m relay'}),
#  ('Vladimir Muravyov', {'4x100m relay'}),
#  ('Andrei Prokofiev', {'4x100m relay'}),
#  ('Nikolai Sidorov', {'4x100m relay'}),
#  ('Ingrid Auerswald-Lange', {'4x100m relay'}),
#  ('Romy Müller', {'4x100m relay'}),
#  ('Nikolai Chernetski', {'4x400m relay'}),
#  ('Mikhail Linge', {'4x400m relay'}),
#  ('Remigius Valiulis', {'4x400m relay'}),
#  ('Tatiana Goishchik', {'4x400m relay'}),
#  ('Irina Nazarova', {'4x400m relay'}),
#  ('Tatiana Prorochenko', {'4x400m relay'}),
#  ('Nina Ziuskova', {'4x400m relay'}),
#  ('Hartwig Gauder', {'50km walk'}),
#  ('Steve Ovett', {'800m'}),
#  ('Nadezhda Olizarenko', {'800m'}),
#  ('Daley Thompson', {'decathlon'}),
#  ('Viktor Rashchupkin', {'discus throw'}),
#  ('Gerd Wessig', {'high jump'}),
#  ('Sara Simeoni', {'high jump'}),
#  ('Dainis Kula', {'javelin throw'}),
#  ('Maria Colon', {'javelin throw'}),
#  ('Lutz Dombrowski', {'long jump'}),
#  ('Tatiana Kolpakova', {'long jump'}),
#  ('Nadezhda Tkachenko', {'pentathlon'}),
#  ('Wladyslaw Kozakiewicz', {'pole vault'}),
#  ('Vladimir Kiselev', {'shot put'}),
#  ('Ilona Schoknecht-Slupianek', {'shot put'}),
#  ('Yaak Uudmae', {'triple jump'}),
#  ('Alberto Cova', {'10000m'}),
#  ('Benita Fitzgerald-Brown', {'100m hurdles'}),
#  ('Roger Kingdom', {'110m hurdles'}),
#  ('Gabriella Dorio', {'1500m'}),
#  ('Ernesto Canto gudino', {'20km walk'}),
#  ('Maricica Puica', {'3000m'}),
#  ('Julius Korir', {'3000m steeplechase'}),
#  ('Nawal El moutawakel', {'400m hurdles'}),
#  ('Ronald James Brown', {'4x100m relay'}),
#  ('Samuel Louis Graddy', {'4x100m relay'}),
#  ('Calvin Smith', {'4x100m relay'}),
#  ('Jeanette Bolden', {'4x100m relay'}),
#  ('Alice Regina Brown', {'4x100m relay'}),
#  ('Raymond Armstead', {'4x400m relay'}),
#  ('Antonio Ricardo Mckay', {'4x400m relay'}),
#  ('Sunder L. Nix', {'4x400m relay'}),
#  ('Sherryl Frances Howard', {'4x400m relay'}),
#  ('Lillie Mae Leatherwood-King', {'4x400m relay'}),
#  ('Said Aouita', {'5000m'}),
#  ('Raul Gonzalez', {'50km walk'}),
#  ('Joaquim Cruz', {'800m'}),
#  ('Doina Besliu-Melinte', {'800m'}),
#  ('Rolf Danneberg', {'discus throw'}),
#  ('Ria G. Stalman', {'discus throw'}),
#  ('Juha Tiainen', {'hammer throw'}),
#  ('Glyniss Leanne Nunn-Saunders-Cearns', {'heptathlon'}),
#  ('Dietmar Mögenburg', {'high jump'}),
#  ('Arto Harkonen', {'javelin throw'}),
#  ('Teresa Sanderson', {'javelin throw'}),
#  ('Anisoara Cusmir-Stanciu', {'long jump'}),
#  ('Carlos Lopes', {'marathon'}),
#  ('Joan Benoit', {'marathon'}),
#  ('Pierre Quinon', {'pole vault'}),
#  ('Alessandro Andrei', {'shot put'}),
#  ('Claudia Losch', {'shot put'}),
#  ('Alfredrick Alphonzo Joyner', {'triple jump'}),
#  ('Moulay Brahim Boutayeb', {'10000m'}),
#  ('Olga Bondarenko', {'10000m'}),
#  ('Yordanka Donkova', {'100m hurdles'}),
#  ('Peter Rono', {'1500m'}),
#  ('Paula Ivan', {'1500m'}),
#  ('Joseph Nathaniel Jr. Deloach', {'200m'}),
#  ('Jozef Pribilinec', {'20km walk'}),
#  ('Tatyana Samolenko-Dorovskikh', {'3000m'}),
#  ('Julius Kariuki', {'3000m steeplechase'}),
#  ('Andre Lamar Phillips', {'400m hurdles'}),
#  ('Deborah Flintoff-King', {'400m hurdles'}),
#  ('Viktor Bryzgin', {'4x100m relay'}),
#  ('Vladimir Krylov', {'4x100m relay'}),
#  ('Vitaly Savin', {'4x100m relay'}),
#  ('Sheila Echols', {'4x100m relay'}),
#  ('Daniel Everett', {'4x400m relay'}),
#  ('Harry Butch . Reynolds', {'4x400m relay'}),
#  ('Kevin Bernard Robinzine', {'4x400m relay'}),
#  ('Tatiana Ledovskaya', {'4x400m relay'}),
#  ('Olga Nazarova', {'4x400m relay'}),
#  ('Mariya Pinigina', {'4x400m relay'}),
#  ('John Ngugi', {'5000m'}),
#  ('Vyacheslav Ivanenko', {'50km walk'}),
#  ('Paul Ereng', {'800m'}),
#  ('Sigrun Wodars', {'800m'}),
#  ('Christian Schenk', {'decathlon'}),
#  ('Jürgen Schult', {'discus throw'}),
#  ('Martina Hellmann', {'discus throw'}),
#  ('Sergei Litvinov', {'hammer throw'}),
#  ('Gennadi Avdeenko', {'high jump'}),
#  ('Dorothy Louise Ritter', {'high jump'}),
#  ('Tapio Korjus', {'javelin throw'}),
#  ('Petra Felke-Meier', {'javelin throw'}),
#  ('Gelindo Bordin', {'marathon'}),
#  ('Rosa Mota', {'marathon'}),
#  ('Sergey Bubka', {'pole vault'}),
#  ('Ulf Timmermann', {'shot put'}),
#  ('Natalya Lisovskaya', {'shot put'}),
#  ('Kristo Gantchev Markov', {'triple jump'}),
#  ('Khalid Skah', {'10000m'}),
#  ('Derartu Tulu', {'10000m'}),
#  ('Yueling Chen', {'10000m walk'}),
#  ('Linford Christie', {'100m'}),
#  ('Paraskevi Voula Patoulidou', {'100m hurdles'}),
#  ('Mark Mckoy', {'110m hurdles'}),
#  ('Fermin Cacho ruiz', {'1500m'}),
#  ('Hassiba Boulmerka', {'1500m'}),
#  ('Daniel Plaza montero', {'20km walk'}),
#  ('Elena Romanova', {'3000m'}),
#  ('Mathew Birir', {'3000m steeplechase'}),
#  ('Kevin Curtis Young', {'400m hurdles'}),
#  ('Sally Janet Jane Gunnell', {'400m hurdles'}),
#  ('Leroy Burrell', {'4x100m relay'}),
#  ('James Jett', {'4x100m relay'}),
#  ('Dennis Mitchell', {'4x100m relay'}),
#  ('Michelle Finn', {'4x100m relay'}),
#  ('Carlette D. Guidry-White', {'4x100m relay'}),
#  ('Esther Jones', {'4x100m relay'}),
#  ('Darnell Hall', {'4x400m relay'}),
#  ('Charles L. Jenkins', {'4x400m relay'}),
#  ('Andrew Valmon', {'4x400m relay'}),
#  ('Marina Chmonina', {'4x400m relay'}),
#  ('Lioudmila Djigalova', {'4x400m relay'}),
#  ('Lilia Nurutdinova', {'4x400m relay'}),
#  ('Yelena Rouzina', {'4x400m relay'}),
#  ('Dieter Baumann', {'5000m'}),
#  ('Andrey Perlov', {'50km walk'}),
#  ('William Tanui', {'800m'}),
#  ('Ellen Van langen', {'800m'}),
#  ('Robert Zmelik', {'decathlon'}),
#  ('Romas Ubartas', {'discus throw'}),
#  ('Maritza Marten', {'discus throw'}),
#  ('Andrey Abduvaliev', {'hammer throw'}),
#  ('Javier Sotomayor', {'high jump'}),
#  ('Heike Henkel', {'high jump'}),
#  ('Jan Zelezny', {'javelin throw'}),
#  ('Silke Renk', {'javelin throw'}),
#  ('Heike Drechsler', {'long jump'}),
#  ('Young-Cho Hwang', {'marathon'}),
#  ('Valentina Yegorova', {'marathon'}),
#  ('Maksim Tarasov', {'pole vault'}),
#  ('Michael D. Stulce', {'shot put'}),
#  ('Svetlana Krivelyova', {'shot put'}),
#  ('Mike Conley', {'triple jump'}),
#  ('Haile Gebrselassie', {'10000m'}),
#  ('Fernanda Ribeiro', {'10000m'}),
#  ('Yelena Nikolayeva', {'10000m walk'}),
#  ('Ludmila Engquist', {'100m hurdles'}),
#  ('Allen Johnson', {'110m hurdles'}),
#  ('Nourredine Morceli', {'1500m'}),
#  ('Jefferson Perez', {'20km walk'}),
#  ('Joseph Keter', {'3000m steeplechase'}),
#  ('Derrick Adkins', {'400m hurdles'}),
#  ('Deon Marie Hemmings', {'400m hurdles'}),
#  ('Carlton Chambers', {'4x100m relay'}),
#  ('Robert Esmie', {'4x100m relay'}),
#  ('Glenroy Gilbert', {'4x100m relay'}),
#  ('Bruny Surin', {'4x100m relay'}),
#  ('Chryste Gaines', {'4x100m relay'}),
#  ('Inger Miller', {'4x100m relay'}),
#  ('Alvin Harrison', {'4x400m relay'}),
#  ('Anthuan Maybank', {'4x400m relay'}),
#  ('Derek Mills', {'4x400m relay'}),
#  ('Jason Rouser', {'4x400m relay'}),
#  ('Lamont Smith', {'4x400m relay'}),
#  ('Kim Graham', {'4x400m relay'}),
#  ('Maicel Malone', {'4x400m relay'}),
#  ('Jearl Miles', {'4x400m relay'}),
#  ('Rochelle Stevens', {'4x400m relay'}),
#  ('Linetta Wilson', {'4x400m relay'}),
#  ('Venuste Niyongabo', {'5000m'}),
#  ('Junxia Wang', {'5000m'}),
#  ('Vebjorn Rodal', {'800m'}),
#  ("Dan O'brien", {'decathlon'}),
#  ('Lars Riedel', {'discus throw'}),
#  ('Ilke Wyludda', {'discus throw'}),
#  ('Balazs Kiss', {'hammer throw'}),
#  ('Ghada Shouaa', {'heptathlon'}),
#  ('Charles Austin', {'high jump'}),
#  ('Stefka Kostadinova', {'high jump'}),
#  ('Heli Orvokki Rantanen', {'javelin throw'}),
#  ('Chioma Ajunwa', {'long jump'}),
#  ('Josia Thugwane', {'marathon'}),
#  ('Fatuma Roba', {'marathon'}),
#  ('Jean Galfione', {'pole vault'}),
#  ('Eric Randolph Barnes', {'shot put'}),
#  ('Astrid Kumbernuss', {'shot put'}),
#  ('Kenny Harrison', {'triple jump'}),
#  ('Inessa Kravets', {'triple jump'}),
#  ('Olga Shishigina', {'100m hurdles'}),
#  ('Anier Garcia', {'110m hurdles'}),
#  ('Noah Kiprono Ngenyi', {'1500m'}),
#  ('Nouria Merah-Benida', {'1500m'}),
#  ('Konstantinos Kenteris', {'200m'}),
#  ('Liping Wang', {'20km race walk'}),
#  ('Reuben Kosgei', {'3000m steeplechase'}),
#  ('Cathy Freeman', {'400m'}),
#  ('Irina Privalova', {'400m hurdles'}),
#  ('Kenneth Brokenburr', {'4x100m relay'}),
#  ('Jon Drummond', {'4x100m relay'}),
#  ('Brian Lewis', {'4x100m relay'}),
#  ('Tim Montgomery', {'4x100m relay'}),
#  ('Bernard Williams iii', {'4x100m relay'}),
#  ('Debbie Ferguson-Mckenzie', {'4x100m relay'}),
#  ('Sevatheda Fynes', {'4x100m relay'}),
#  ('Eldice Lewis', {'4x100m relay'}),
#  ('Chandra Sturrup', {'4x100m relay'}),
#  ('Andrea Anderson', {'4x400m relay'}),
#  ('LaTasha Colander', {'4x400m relay'}),
#  ('Monique Hennagan', {'4x400m relay'}),
#  ('Millon Wolde', {'5000m'}),
#  ('Gabriela Szabo', {'5000m'}),
#  ('Nils Schumann', {'800m'}),
#  ('Maria Mutola', {'800m'}),
#  ('Erki Nool', {'decathlon'}),
#  ('Virgilijus Alekna', {'discus throw'}),
#  ('Ellina Zvereva', {'discus throw'}),
#  ('Szymon Ziolkowski', {'hammer throw'}),
#  ('Kamila Skolimowska', {'hammer throw'}),
#  ('Denise Lewis', {'heptathlon'}),
#  ('Sergey Kliugin', {'high jump'}),
#  ('Yelena Yelesina', {'high jump'}),
#  ('Trine Hattestad', {'javelin throw'}),
#  ('Ivan Pedroso', {'long jump'}),
#  ('Gezahegne Abera', {'marathon'}),
#  ('Naoko Takahashi', {'marathon'}),
#  ('Nick Hysong', {'pole vault'}),
#  ('Stacy Dragila', {'pole vault'}),
#  ('Arsi Harju', {'shot put'}),
#  ('Yanina Karolchik', {'shot put'}),
#  ('Jonathan David Edwards', {'triple jump'}),
#  ('Tereza Marinova', {'triple jump'}),
#  ('Huina Xing', {'10000m'}),
#  ('Justin Gatlin', {'100m'}),
#  ('Yuliya Nesterenko', {'100m'}),
#  ('Joanna Hayes', {'100m hurdles'}),
#  ('Xiang Liu', {'110m hurdles'}),
#  ('Shawn Crawford', {'200m'}),
#  ('Athanasia Tsoumeleka', {'20km race walk'}),
#  ('Ivano Brugnetti', {'20km walk'}),
#  ('Ezekiel Kemboi', {'3000m steeplechase'}),
#  ('Tonique Williams-Darling', {'400m'}),
#  ('Felix Sanchez', {'400m hurdles'}),
#  ('Fani Chalkia', {'400m hurdles'}),
#  ('Darren Campbell', {'4x100m relay'}),
#  ('Marlon Devonish', {'4x100m relay'}),
#  ('Jason Gardener', {'4x100m relay'}),
#  ('Mark Lewis-Francis', {'4x100m relay'}),
#  ('Aleen Bailey', {'4x100m relay'}),
#  ('Tanya Lawrence', {'4x100m relay'}),
#  ('Beverly Mcdonald', {'4x100m relay'}),
#  ('Sherone Simpson', {'4x100m relay'}),
#  ('Derrick Brew', {'4x400m relay'}),
#  ('Otis Harris', {'4x400m relay'}),
#  ('Darold Williamson', {'4x400m relay'}),
#  ('Kelly Willie', {'4x400m relay'}),
#  ('Crystal Cox', {'4x400m relay'}),
#  ('Monique Henderson', {'4x400m relay'}),
#  ('Sanya Richards', {'4x400m relay'}),
#  ('Moushaumi Robinson', {'4x400m relay'}),
#  ('Deedee Trotter', {'4x400m relay'}),
#  ('Yuriy Borzakovskiy', {'800m'}),
#  ('Roman Sebrle', {'decathlon'}),
#  ('Natalya Sadova', {'discus throw'}),
#  ('Koji Murofushi', {'hammer throw'}),
#  ('Olga Kuzenkova', {'hammer throw'}),
#  ('Carolina Kluft', {'heptathlon'}),
#  ('Stefan Holm', {'high jump'}),
#  ('Elena Slesarenko', {'high jump'}),
#  ('Andreas Thorkildsen', {'javelin throw'}),
#  ('Osleidys Menendez', {'javelin throw'}),
#  ('Dwight Phillips', {'long jump'}),
#  ('Tatyana Lebedeva', {'long jump'}),
#  ('Stefano Baldini', {'marathon'}),
#  ('Mizuki Noguchi', {'marathon'}),
#  ('Timothy Mack', {'pole vault'}),
#  ('Elena Isinbaeva', {'pole vault'}),
#  ('Yuriy Bilonog', {'shot put'}),
#  ('Yumileidi Cumba', {'shot put'}),
#  ('Christian Olsson', {'triple jump'}),
#  ('Francoise Mbango etone', {'triple jump'}),
#  ('Shelly-Ann Fraser', {'100m'}),
#  ('Dawn Harper', {'100m hurdles'}),
#  ('Dayron Robles', {'110m hurdles'}),
#  ('Asbel Kipruto Kiprop', {'1500m'}),
#  ('Nancy jebet Langat', {'1500m'}),
#  ('Olga Kaniskina', {'20km race walk'}),
#  ('Valeriy Borchin', {'20km walk'}),
#  ('Brimin Kiprop Kipruto', {'3000m steeplechase'}),
#  ('Gulnara Galkina-Samitova', {'3000m steeplechase'}),
#  ('Christine Ohuruogu', {'400m'}),
#  ('Melaine Walker', {'400m hurdles'}),
#  ('Nesta Carter', {'4x100m relay'}),
#  ('Michael Frater', {'4x100m relay'}),
#  ('Asafa Powell', {'4x100m relay'}),
#  ('Yuliya Chermoshanskaya', {'4x100m relay'}),
#  ('Aleksandra Fedoriva', {'4x100m relay'}),
#  ('Yulia Gushchina', {'4x100m relay'}),
#  ('Evgeniya Polyakova', {'4x100m relay'}),
#  ('David Neville', {'4x400m relay'}),
#  ('Mary Wineberg', {'4x400m relay'}),
#  ('Alex Schwazer', {'50km walk'}),
#  ('Wilfred Bungei', {'800m'}),
#  ('Pamela Jelimo', {'800m'}),
#  ('Bryan Clay', {'decathlon'}),
#  ('Gerd Kanter', {'discus throw'}),
#  ('Stephanie Brown trafton', {'discus throw'}),
#  ('Primoz Kozmus', {'hammer throw'}),
#  ('Aksana Miankova', {'hammer throw'}),
#  ('Nataliia Dobrynska', {'heptathlon'}),
#  ('Andrey Silnov', {'high jump'}),
#  ('Tia Hellebaut', {'high jump'}),
#  ('Barbora Spotakova', {'javelin throw'}),
#  ('Irving Jahir Saladino aranda', {'long jump'}),
#  ('Maurren Higa Maggi', {'long jump'}),
#  ('Samuel Kamau Wansiru', {'marathon'}),
#  ('Constantina Tomescu', {'marathon'}),
#  ('Steve Hooker', {'pole vault'}),
#  ('Tomasz Majewski', {'shot put'}),
#  ('Valerie Vili', {'shot put'}),
#  ('Nelson Evora', {'triple jump'}),
#  ('Shelly-Ann Fraser-Pryce', {'100m'}),
#  ('Yohan Blake', {'4x100m relay'}),
#  ('Carmelita Jeter', {'4x100m relay'}),
#  ('Natalya Antyukh', {'400m hurdles'}),
#  ('DeeDee Trotter', {'4x400m relay'}),
#  ('Yuliya Zaripova', {'3000m steeplechase'}),
#  ('Ivan Ukhov', {'high jump'}),
#  ('Anna Chicherova', {'high jump'}),
#  ('Tatyana Lysenko', {'hammer throw'}),
#  ('Sergey Kirdyapkin', {'50km walk'}),
#  ('Elena Lashmanova', {'20km walk'}),
#  ('Mariya Savinova', {'800m'}),
#  ('Valerie Adams', {'shot put'}),
#  ('David Lekuta Rudisha', {'800m'}),
#  ('Olga Rypakova', {'triple jump'}),
#  ('Robert Harting', {'discus throw'}),
#  ('Krisztian Pars', {'hammer throw'}),
#  ('Kirani James', {'400m'}),
#  ('Jessica Ennis', {'heptathlon'}),
#  ('Kemar Bailey-Cole', {'4x100m relay'}),
#  ('Tiki Gelana', {'marathon'}),
#  ('Alistair Brownlee', {'triathlon (long jump / shot put / 100 yards)'}),
#  ('Greg Rutherford', {'long jump'}),
#  ('Renaud Lavillenie', {'pole vault'}),
#  ('Sally Pearson', {'100m hurdles'}),
#  ('Taoufik Makhloufi', {'1500m'}),
#  ('Ding Chen', {'20km walk'}),
#  ('Sandra Perkovic', {'discus throw'}),
#  ('Chris Brown', {'4x400m relay'}),
#  ('Michael Mathieu', {'4x400m relay'}),
#  ('Ramon Miller', {'4x400m relay'}),
#  ('Demetrius Pinder', {'4x400m relay'}),
#  ('Lauryn Williams', {'4x100m relay'}),
#  ('Jennifer Suhr', {'pole vault'}),
#  ('Ashton Eaton', {'decathlon'}),
#  ('Keshia Baker', {'4x400m relay'}),
#  ('Diamond Dixon', {'4x400m relay'}),
#  ('Brittney Reese', {'long jump'}),
#  ('Keshorn Walcott', {'javelin throw'}),
#  ('Stephen Kiprotich', {'marathon'}),
#  ('Alptekin Asli Cakir', {'1500m'}),
#  ('Nicola Spirig', {'triathlon (long jump / shot put / 100 yards)'}),
#  ('Christian Taylor', {'triple jump'}),
#  ('Bianca Knight', {'4x100m relay'}),
#  ('Aries Merritt', {'110m hurdles'}),
#  ('Jeneba Tarmoh', {'4x100m relay'}),
#  ('Tianna Madison', {'4x100m relay'}),
#  ('Francena McCorory', {'4x400m relay'}),
#  ('Tori Bowie', {'4x100m relay'}),
#  ('Vivian Jepkemoi Cheruiyot', {'5000m team'}),
#  ('Almaz Ayana', {'10miles walk (16093m)'}),
#  ('Lashawn Merritt', {'4x400m relay'}),
#  ('Morolake Akinosun', {'4x100m relay'}),
#  ('Nickel Ashmeade', {'4x100m relay'}),
#  ('Ruth Beitia', {'high jump'}),
#  ('Michelle Carter', {'shot put'}),
#  ('Matthew Centrowitz', {'1500m'}),
#  ('Kerron Clement', {'400m hurdles'}),
#  ('Kyle Clemons', {'4x400m relay'}),
#  ('Ryan Crouser', {'shot put'}),
#  ('Thiago Braz Da Silva', {'pole vault'}),
#  ('Derek Drouin', {'high jump'}),
#  ('Taylor Ellis-Watson', {'4x400m relay'}),
#  ('Phyllis Francis', {'4x400m relay'}),
#  ('English Gardner', {'4x100m relay'}),
#  ('Arman Hall', {'4x400m relay'}),
#  ('Christoph Harting', {'discus throw'}),
#  ('Natasha Hastings', {'4x400m relay'}),
#  ('Jeff Henderson', {'long jump'}),
#  ('Caterine Ibarguen', {'triple jump'}),
#  ('Ruth Jebet', {'3000m steeplechase'}),
#  ('Gwen Jorgensen', {'triathlon (long jump / shot put / 100 yards)'}),
#  ('Eliud Kipchoge', {'marathon'}),
#  ('Conseslus Kipruto', {'3000m steeplechase'}),
#  ('Faith Chepngetich Kipyegon', {'1500m'}),
#  ('Sara Kolak', {'javelin throw'}),
#  ('Hong Liu', {'20km walk'}),
#  ('Francena Mccorory', {'4x400m relay'}),
#  ('Omar Mcleod', {'110m hurdles'}),
#  ('Tony Mcquay', {'4x400m relay'}),
#  ('Shaunae Miller', {'400m'}),
#  ('Jevaughn Minzie', {'4x100m relay'}),
#  ('Dalilah Muhammad', {'400m hurdles'}),
#  ('Dilshod Nazarov', {'hammer throw'}),
#  ('Courtney Okolo', {'4x400m relay'}),
#  ('Jenna Prandini', {'4x100m relay'}),
#  ('Gil Roberts', {'4x400m relay'}),
#  ('Thomas Rohler', {'javelin throw'}),
#  ('Brianna Rollins', {'100m hurdles'}),
#  ('Caster Semenya', {'800m'}),
#  ('Ekaterini Stefanidi', {'pole vault'}),
#  ('Jemima Jelagat Sumgong', {'marathon'}),
#  ('Nafissatou Thiam', {'heptathlon'}),
#  ('Matej Toth', {'50km walk'}),
#  ('NIEKERK Wayde Van', {'400m'}),
#  ('David Verburg', {'4x400m relay'}),
#  ('Zhen Wang', {'20km walk'}),
#  ('Ariana Washington', {'4x100m relay'}),
#  ('Anita Wlodarczyk', {'hammer throw'})]
